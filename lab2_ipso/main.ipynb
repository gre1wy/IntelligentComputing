# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
def plot_function_3d(func, x_range, y_range, title=""):

    x = np.linspace(x_range[0], x_range[1], 100)
    y = np.linspace(y_range[0], y_range[1], 100)
    X, Y = np.meshgrid(x, y)
    Z = np.array([[func(np.array([xi, yi])) for xi in x] for yi in y])
    
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    surf = ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none', alpha=0.8)
    ax.set_title(title)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    fig.colorbar(surf, shrink=0.5, aspect=10)
    plt.show()

def plot_function_contour(func, x_range, y_range, title=""):

    x = np.linspace(x_range[0], x_range[1], 200)
    y = np.linspace(y_range[0], y_range[1], 200)
    X, Y = np.meshgrid(x, y)
    Z = np.array([[func(np.array([xi, yi])) for xi in x] for yi in y])
    
    plt.figure(figsize=(8,6))
    cp = plt.contourf(X, Y, Z, 50, cmap='viridis')
    plt.title(title)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.colorbar(cp)
    plt.show()
    
# plot_function_3d(ackley, (-5, 5), (-5, 5), title="Ackley Function (3D Surface)")
# plot_function_contour(ackley, (-5, 5), (-5, 5), title="Ackley Function (Contour)")

# plot_function_3d(rosenbrock, (-2, 2), (-1, 3), title="Rosenbrock Function (3D Surface)")
# plot_function_contour(rosenbrock, (-2, 2), (-1, 3), title="Rosenbrock Function (Contour)")

# plot_function_3d(cross_in_tray, (-10, 10), (-10, 10), title="Cross-in-tray Function (3D Surface)")
# plot_function_contour(cross_in_tray, (-10, 10), (-10, 10), title="Cross-in-tray Function (Contour)")

# plot_function_3d(holder_table, (-10, 10), (-10, 10), title="Holder Table Function (3D Surface)")
# plot_function_contour(holder_table, (-10, 10), (-10, 10), title="Holder Table Function (Contour)")

# plot_function_3d(mccormick, (-1.5, 4), (-3, 4), title="McCormick Function (3D Surface)")
# plot_function_contour(mccormick, (-1.5, 4), (-3, 4), title="McCormick Function (Contour)")

# plot_function_3d(styblinski_tang, (-5, 5), (-5, 5), title="Styblinski–Tang Function (3D Surface)")
# plot_function_contour(styblinski_tang, (-5, 5), (-5, 5), title="Styblinski–Tang Function (Contour)")

# %%
class Particle:
    def __init__(self, dim, pos_bounds, vel_bounds):
        """
        Initializes a particle with random position and velocity.
        
        Parameters:
            dim (int): Dimensionality of the search space.
            pos_bounds (tuple): (x_min, x_max) boundaries for positions.
            vel_bounds (tuple): (v_min, v_max) boundaries for velocities.
        """
        self.dim = dim
        self.pos_bounds = pos_bounds
        self.vel_bounds = vel_bounds
        self.position = np.random.uniform(pos_bounds[0], pos_bounds[1], dim)
        self.velocity = np.random.uniform(vel_bounds[0], vel_bounds[1], dim)
        self.best_position = self.position.copy()
        self.best_score = float('inf')

    def update_velocity(self, global_best, w, alpha1, alpha2):
        """
        Updates the particle's velocity based on inertia, cognitive, and social components.
        
        Parameters:
            global_best (ndarray): The best position found by the swarm.
            w (float): Inertia weight.
            alpha1 (float): Cognitive acceleration coefficient.
            alpha2 (float): Social acceleration coefficient.
        """
        r1, r2 = np.random.rand(2)
        cognitive = alpha1 * r1 * (self.best_position - self.position)
        social = alpha2 * r2 * (global_best - self.position)
        self.velocity = w * self.velocity + cognitive + social

    def update_position(self):
        """
        Updates the particle's position based on its velocity and applies boundary reflection.
        """
        self.position += self.velocity
        # Reflect the particle if it goes out of bounds
        for j in range(self.dim):
            if self.position[j] < self.pos_bounds[j, 0]:
                self.position[j] = self.pos_bounds[j, 0] + abs(self.position[j] - self.pos_bounds[j, 0])
                self.velocity[j] = -self.velocity[j]
            elif self.position[j] > self.pos_bounds[j, 1]:
                self.position[j] = self.pos_bounds[j, 1] - abs(self.position[j] - self.pos_bounds[j, 1])
                self.velocity[j] = -self.velocity[j]

class PSO:
    def __init__(self, fitness_func, num_particles, dim, pos_bounds, vel_bounds, max_iter, 
                 alpha1, alpha2, w_max, w_min, 
                 enable_shaking=False, stagnation_iter=50, shake_probability=0.5, shake_amplitude=0.1,
                 target_global_min=None, epsilon_target=None, epsilon_stagnation=1e-6):
        """
        Parameters:
            fitness_func (callable): The objective function.
            num_particles (int): Number of particles.
            dim (int): Dimensionality of the search space.
            pos_bounds (tuple): (x_min, x_max) boundaries for positions.
            vel_bounds (tuple): (v_min, v_max) boundaries for velocities.
            max_iter (int): Maximum number of iterations.
            alpha1, alpha2 (float): Acceleration coefficients.
            w_max, w_min (float): Maximum and minimum inertia weights.
            enable_shaking (bool): Whether to enable the shaking mechanism.
            stagnation_iter (int): Iterations with negligible improvement before shaking is triggered.
            shake_probability (float): Probability that a particle is shaken.
            shake_amplitude (float): Amplitude of the shake (fraction of the position range).
            target_global_min (float): Stop if the global best score is below this value.
            epsilon_target (float): Stop if the difference between global best score and the target is less than this.
            epsilon_stagnation (float): Threshold for change in global best score to be considered as stagnation.
        """
        self.fitness_func = fitness_func
        self.num_particles = num_particles
        self.dim = dim
        self.pos_bounds = pos_bounds
        self.vel_bounds = vel_bounds
        self.max_iter = max_iter
        self.alpha1 = alpha1
        self.alpha2 = alpha2
        self.w_max = w_max
        self.w_min = w_min

        self.target_global_min = target_global_min
        self.epsilon_target = epsilon_target

        self.enable_shaking = enable_shaking
        self.epsilon_stagnation = epsilon_stagnation
        self.stagnation_iter = stagnation_iter
        self.shake_probability = shake_probability
        self.shake_amplitude = shake_amplitude

        
        # Create the swarm of particles
        self.swarm = [Particle(dim, pos_bounds, vel_bounds) for _ in range(num_particles)]
        self.global_best_position = None
        self.global_best_score = float('inf')
        self.history_best_positions = []  
        self.history_all_positions = []   
        
        # Initialize global best from the swarm
        for particle in self.swarm:
            score = self.fitness_func(particle.position)
            particle.best_score = score
            if score < self.global_best_score:
                self.global_best_score = score
                self.global_best_position = particle.position.copy()
    
    def shake_particles(self):
        """
        Applies a random perturbation to particle positions and reinitializes velocities.
        """
        range_pos = np.abs(self.pos_bounds[1] - self.pos_bounds[0])  

        shake_std = np.maximum(self.shake_amplitude * range_pos, 1e-6)

        shaken_count = 0
        for particle in self.swarm:
            if np.random.rand() < self.shake_probability:
                noise = np.random.normal(0, shake_std, self.dim)
                particle.position += noise
                particle.velocity = np.random.uniform(self.vel_bounds[0], self.vel_bounds[1], self.dim)
                particle.best_position = particle.position.copy()
                particle.best_score = self.fitness_func(particle.position)
                shaken_count += 1
        print(f"Shaken {shaken_count} particles.")
        
    def run(self):
        """
        Executes the PSO algorithm.
        
        Returns:
            (global_best_position, global_best_score, history_best_positions, history_all_positions)
        """
        stagnation_count = 0
        previous_best = self.global_best_score
        
        for iteration in range(self.max_iter):
            # Update inertia weight linearly
            w = self.w_max - ((self.w_max - self.w_min) * iteration / self.max_iter)
            for particle in self.swarm:
                particle.update_velocity(self.global_best_position, w, self.alpha1, self.alpha2)
                particle.update_position()
                score = self.fitness_func(particle.position)
                # Update personal best for each particle
                if score < particle.best_score:
                    particle.best_score = score
                    particle.best_position = particle.position.copy()
                # Update global best for the swarm
                if score < self.global_best_score:
                    self.global_best_score = score
                    self.global_best_position = particle.position.copy()
            
            # Save history of the global best position and all particle positions
            self.history_best_positions.append(self.global_best_position.copy())
            iteration_positions = [particle.position.copy() for particle in self.swarm]
            self.history_all_positions.append(iteration_positions)
            
            # Check stagnation: if the improvement is less than epsilon_stagnation, increase counter
            if abs(previous_best - self.global_best_score) < self.epsilon_stagnation:
                stagnation_count += 1
            else:
                stagnation_count = 0
                previous_best = self.global_best_score
            
            # Trigger shaking if stagnation persists
            if self.enable_shaking and stagnation_count >= self.stagnation_iter:
                print(f"Stagnation reached at iteration {iteration}. Shaking particles...")
                self.shake_particles()
                stagnation_count = 0  # Reset stagnation counter
            
            # Check stopping conditions based on target global minimum
            if self.target_global_min is not None:
                if self.global_best_score <= self.target_global_min:
                    print(f"Target global minimum {self.target_global_min} reached at iteration {iteration}. Stopping.")
                    break
                if self.epsilon_target is not None and abs(self.global_best_score - self.target_global_min) < self.epsilon_target:
                    print(f"Global minimum is within epsilon {self.epsilon_target} of target at iteration {iteration}. Stopping.")
                    break
            
            if iteration % 10 == 0:
                print(f"Iteration {iteration}: Global best score = {self.global_best_score}")
        
        return self.global_best_position, self.global_best_score, self.history_best_positions, self.history_all_positions

# %% [markdown]
# # Visualisation

# %%
def ackley(x, a=20, b=0.2, c=2*np.pi):
    d = len(x)
    sum_sq = np.sum(x**2)
    sum_cos = np.sum(np.cos(c * x))
    term1 = -a * np.exp(-b * np.sqrt(sum_sq / d))
    term2 = -np.exp(sum_cos / d)
    return term1 + term2 + a + np.exp(1)

def rosenbrock(x):
    return np.sum(100.0*(x[1:] - x[:-1]**2.0)**2.0 + (1 - x[:-1])**2.0)

def cross_in_tray(x):
    term1 = np.sin(x[0]) * np.sin(x[1])
    term2 = np.exp(np.abs(100 - np.sqrt(x[0]**2 + x[1]**2)/np.pi))
    return -0.0001 * (np.abs(term1 * term2) + 1)**0.1

def holder_table(x):
    return -np.abs(np.sin(x[0]) * np.cos(x[1]) * 
                   np.exp(np.abs(1 - np.sqrt(x[0]**2 + x[1]**2)/np.pi)))

def mccormick(x):
    return np.sin(x[0] + x[1]) + (x[0] - x[1])**2 - 1.5*x[0] + 2.5*x[1] + 1

def styblinski_tang(x):
    return 0.5 * np.sum(x**4 - 16*x**2 + 5*x)

# %%
func_info = {
    "ackley": (ackley, (-5, 5), (-5, 5), (0, 0), 0),
    "rosenbrock": (rosenbrock, (-5, 5), (-5, 5), (1, 1), 0),
    "cross_in_tray": (cross_in_tray, (-10, 10), (-10, 10), (1.34941, 1.34941), -2.06261),
    "holder_table": (holder_table, (-10, 10), (-10, 10), (8.05502, 9.66459), -19.2085),
    "mccormick": (mccormick, (-1.5, 4), (-3, 4), (-0.54719, -1.54719), -1.9133),
    "styblinski_tang": (styblinski_tang, (-5, 5), (-5, 5), (-2.903534, -2.903534), -78.33198)
}

# %% [markdown]
# ## Find optimal parametrs

# %%
num_runs = 10
num_particles_values = [20, 50, 100, 250, 500]
alpha1_values = [1, 1.5, 2]
alpha2_values = [1, 1.5, 2]
results = {}

max_iter = 200
w_max = 0.9
w_min = 0.2
epsilon_target = 1e-6

enable_shaking = False
stagnation_iter = 50
shake_probability = 0.5
shake_amplitude = 0.3
epsilon_stagnation = 1e-6


start = True

if start:
    for func_name, (func, x_bound, y_bound, best_point, theoretical_min) in func_info.items():
        bounds = np.array([x_bound, y_bound])
        
        best_avg_cost = None
        best_params = None
        param_results = {}
        
        for n in num_particles_values:
            for a1 in alpha1_values:
                for a2 in alpha2_values:
                    cost_list = []
                    for run in range(num_runs):
                        pso_solver = PSO(func, n, 2, bounds, (-2, 2), max_iter,
                                        a1, a2, w_max, w_min,
                                        enable_shaking, stagnation_iter, shake_probability, shake_amplitude,
                                        target_global_min=theoretical_min, epsilon_target=epsilon_target, epsilon_stagnation=epsilon_stagnation)
                        _, best_score, history_best_positions, _ = pso_solver.run()
                        iters = len(history_best_positions)
                        cost = n * iters  # Total cost: number of particles multiplied by iterations
                        cost_list.append(cost)
                    
                    avg_cost = np.mean(cost_list)
                    param_results[(n, a1, a2)] = avg_cost
                    
                    if best_avg_cost is None or avg_cost < best_avg_cost:
                        best_avg_cost = avg_cost
                        best_params = (n, a1, a2)
        
        results[func_name] = (best_params, best_avg_cost, param_results)
        print(f"Function: {func_name}")
        print(f"Best parameters: num_particles = {best_params[0]}, alpha1 = {best_params[1]}, alpha2 = {best_params[2]}")
        print(f"Average cost (num_particles * iterations): {best_avg_cost:.2f}")
        print("-" * 50)
# Out:
# Iteration 0: Global best score = 11.913942381520288
# Iteration 10: Global best score = 0.14593818526602975
# Iteration 20: Global best score = 0.04333972870514957
# Iteration 30: Global best score = 0.019275624819279802
# Iteration 40: Global best score = 0.018520450969628843
# Iteration 50: Global best score = 0.009990014005648806
# Iteration 60: Global best score = 0.003961179131359405
# Iteration 70: Global best score = 0.003317390730881886
# Iteration 80: Global best score = 0.003268444707150042
# Iteration 90: Global best score = 0.002375040322835975
# Iteration 100: Global best score = 0.0006098709028994342
# Iteration 110: Global best score = 2.1749254259351147e-05
# Iteration 120: Global best score = 2.2758070277184572e-06
# Global minimum is within epsilon 1e-06 of target at iteration 128. Stopping.
# Iteration 0: Global best score = 9.911577119486378
# Iteration 10: Global best score = 0.265918523266198
# Iteration 20: Global best score = 0.1597311283082239
# Iteration 30: Global best score = 0.08624199238011743
# Iteration 40: Global best score = 0.02801726673985927
# Iteration 50: Global best score = 0.022668793059164916
# Iteration 60: Global best score = 0.019208795751524566
# Iteration 70: Global best score = 0.007887124306194426
# Iteration 80: Global best score = 0.005203992309251948
# Iteration 90: Global best score = 0.0038725555558767333
# Iteration 100: Global best score = 0.00012881191125702074
# Iteration 110: Global best score = 1.8120402451859974e-05
# Iteration 120: Global best score = 1.514998491547459e-06
# Global minimum is within epsilon 1e-06 of target at iteration 130. Stopping.
# Iteration 0: Global best score = 11.774577509370108
# Iteration 10: Global best score = 0.34272992023052185
# Iteration 20: Global best score = 0.05164940571010179
# Iteration 30: Global best score = 0.04680719948734735
# Iteration 40: Global best score = 0.014672840695187706
# Iteration 50: Global best score = 0.014672840695187706
# Iteration 60: Global best score = 0.005133847556255677
# Iteration 70: Global best score = 0.0026781805008799786
# Iteration 80: Global best score = 0.0006189576401749441
# Iteration 90: Global best score = 0.000589252536422169
# Iteration 100: Global best score = 0.00011770501742747186
# Iteration 110: Global best score = 2.8183386583169323e-05
# Iteration 120: Global best score = 1.345076908920717e-05
# Iteration 130: Global best score = 1.5804265456331734e-06
# Global minimum is within epsilon 1e-06 of target at iteration 133. Stopping.
# Iteration 0: Global best score = 10.343275814276458
# Iteration 10: Global best score = 0.21551391335118852
# Iteration 20: Global best score = 0.022400186290948643
# Iteration 30: Global best score = 0.022400186290948643
# Iteration 40: Global best score = 0.019209410231863178
# Iteration 50: Global best score = 0.015774973424119043
# Iteration 60: Global best score = 0.01284033267123208
# Iteration 70: Global best score = 0.003397486809810335
# Iteration 80: Global best score = 0.0017729471602661029
# Iteration 90: Global best score = 0.00027898535863757346
# Iteration 100: Global best score = 2.9694745059760663e-05
# Iteration 110: Global best score = 1.2891208527765485e-05
# Iteration 120: Global best score = 1.2008387234363482e-05
# Iteration 130: Global best score = 1.607073514708901e-06
# Global minimum is within epsilon 1e-06 of target at iteration 132. Stopping.
# Iteration 0: Global best score = 11.142598539155928
# Iteration 10: Global best score = 0.9854690718293821
# Iteration 20: Global best score = 0.049819577747932886
# Iteration 30: Global best score = 0.026025383807255498
# Iteration 40: Global best score = 0.025804537888991508
# Iteration 50: Global best score = 0.017823179437268966
# Iteration 60: Global best score = 0.007468409589045155
# Iteration 70: Global best score = 0.005713131305313812
# Iteration 80: Global best score = 0.004032162996385313
# Iteration 90: Global best score = 0.0033723639847456077
# Iteration 100: Global best score = 0.0028958862763706072
# Iteration 110: Global best score = 0.00013267386841819828
# Iteration 120: Global best score = 1.1442030800612457e-05
# Iteration 130: Global best score = 1.5636666934604193e-06
# Global minimum is within epsilon 1e-06 of target at iteration 136. Stopping.
# Iteration 0: Global best score = 10.468754418665164
# Iteration 10: Global best score = 0.9806017777858433
# Iteration 20: Global best score = 0.06964935829393726
# Iteration 30: Global best score = 0.01621729101052738
# Iteration 40: Global best score = 0.01621729101052738
# Iteration 50: Global best score = 0.011847625065190659
# Iteration 60: Global best score = 0.01089057901213808
# Iteration 70: Global best score = 0.010199809261678627
# Iteration 80: Global best score = 0.007834558977240835
# Iteration 90: Global best score = 0.0046713072467388095
# Iteration 100: Global best score = 0.00017950223759344297
# Iteration 110: Global best score = 8.683530087427727e-06
# Iteration 120: Global best score = 2.28651643086053e-06
# Global minimum is within epsilon 1e-06 of target at iteration 124. Stopping.
# Iteration 0: Global best score = 10.966792766616804
# Iteration 10: Global best score = 0.32703630032004627
# Iteration 20: Global best score = 0.014273674589518226
# Iteration 30: Global best score = 0.008439711790267257
# Iteration 40: Global best score = 0.008439711790267257
# Iteration 50: Global best score = 0.007787659236811795
# Iteration 60: Global best score = 0.005516904716590165
# Iteration 70: Global best score = 0.003741985935868275
# Iteration 80: Global best score = 0.002978418289000917
# Iteration 90: Global best score = 0.0019815526685502682
# Iteration 100: Global best score = 0.0004920393161467196
# Iteration 110: Global best score = 3.6594522665911455e-05
# Iteration 120: Global best score = 2.7614803745912297e-06
# Iteration 130: Global best score = 1.3599533983388312e-06
# Global minimum is within epsilon 1e-06 of target at iteration 131. Stopping.
# Iteration 0: Global best score = 10.265105867262218
# Iteration 10: Global best score = 0.5119554001615509
# Iteration 20: Global best score = 0.4445729103480862
# Iteration 30: Global best score = 0.027047180471918342
# Iteration 40: Global best score = 0.027047180471918342
# Iteration 50: Global best score = 0.027047180471918342
# Iteration 60: Global best score = 0.022998369563815846
# Iteration 70: Global best score = 0.012822097160260615
# Iteration 80: Global best score = 0.008652629500283116
# Iteration 90: Global best score = 0.0013517372243900816
# Iteration 100: Global best score = 7.063727032319278e-05
# Iteration 110: Global best score = 9.221093002498293e-06
# Iteration 120: Global best score = 4.213946358522236e-06
# Iteration 130: Global best score = 1.595364107931374e-06
# Global minimum is within epsilon 1e-06 of target at iteration 133. Stopping.
# Iteration 0: Global best score = 11.605876636928397
# Iteration 10: Global best score = 0.3003377820811193
# Iteration 20: Global best score = 0.25818113471342885
# Iteration 30: Global best score = 0.25818113471342885
# Iteration 40: Global best score = 0.09692963619782491
# Iteration 50: Global best score = 0.025076194410527552
# Iteration 60: Global best score = 0.0021481032117915966
# Iteration 70: Global best score = 0.0021481032117915966
# Iteration 80: Global best score = 0.00044943401671249106
# Iteration 90: Global best score = 0.000259215696566617
# Iteration 100: Global best score = 4.15998834175646e-05
# Iteration 110: Global best score = 3.050821188610442e-05
# Iteration 120: Global best score = 1.8386718754204168e-05
# Iteration 130: Global best score = 1.124766054960702e-06
# Global minimum is within epsilon 1e-06 of target at iteration 131. Stopping.
# Iteration 0: Global best score = 11.835550305620115
# Iteration 10: Global best score = 1.5249272683077177
# Iteration 20: Global best score = 0.9151429595509097
# Iteration 30: Global best score = 0.18182441915516678
# Iteration 40: Global best score = 0.04975930744259971
# Iteration 50: Global best score = 0.03569556328600543
# Iteration 60: Global best score = 0.03276346510791628
# Iteration 70: Global best score = 0.01576344642819949
# Iteration 80: Global best score = 0.0028756405528267415
# Iteration 90: Global best score = 0.0002234754532932648
# Iteration 100: Global best score = 4.384411432356572e-05
# Iteration 110: Global best score = 3.0291374667701376e-05
# Iteration 120: Global best score = 1.612585466803651e-05
# Iteration 130: Global best score = 1.5869344207608549e-06
# Global minimum is within epsilon 1e-06 of target at iteration 137. Stopping.
# Iteration 0: Global best score = 11.167507690312597
# Iteration 10: Global best score = 1.4816697636414102
# Iteration 20: Global best score = 0.4106036951045344
# Iteration 30: Global best score = 0.013488130124781339
# Iteration 40: Global best score = 0.013488130124781339
# Iteration 50: Global best score = 0.013488130124781339
# Iteration 60: Global best score = 0.010940649191916396
# Iteration 70: Global best score = 0.010029639204983898
# Iteration 80: Global best score = 0.002882109509770192
# Iteration 90: Global best score = 0.0003865675137189051
# Iteration 100: Global best score = 0.00011913255008311197
# Iteration 110: Global best score = 1.1460416850628263e-05
# Iteration 120: Global best score = 3.2879489144654883e-06
# Global minimum is within epsilon 1e-06 of target at iteration 126. Stopping.
# Iteration 0: Global best score = 9.87270690766485
# Iteration 10: Global best score = 2.1510471750227933
# Iteration 20: Global best score = 0.13016782231341795
# Iteration 30: Global best score = 0.09795663325380177
# Iteration 40: Global best score = 0.08647414376542573
# Iteration 50: Global best score = 0.0277221908297709
# Iteration 60: Global best score = 0.009160744984616276
# Iteration 70: Global best score = 0.005452333129575937
# Iteration 80: Global best score = 0.0016562270121984746
# Iteration 90: Global best score = 0.0001391683814842004
# Iteration 100: Global best score = 4.644842808376737e-05
# Iteration 110: Global best score = 8.965231672153351e-06
# Iteration 120: Global best score = 6.610306944043742e-06
# Iteration 130: Global best score = 1.4876921778927965e-06
# Global minimum is within epsilon 1e-06 of target at iteration 132. Stopping.
# Iteration 0: Global best score = 9.160376254120301
# Iteration 10: Global best score = 0.40961864238902423
# Iteration 20: Global best score = 0.048845337791484145
# Iteration 30: Global best score = 0.048845337791484145
# Iteration 40: Global best score = 0.030760885821120798
# Iteration 50: Global best score = 0.005298596408711109
# Iteration 60: Global best score = 0.005298596408711109
# Iteration 70: Global best score = 0.0042989929881263045
# Iteration 80: Global best score = 0.0010428817110335054
# Iteration 90: Global best score = 0.0005257275895478308
# Iteration 100: Global best score = 0.00040644142337997735
# Iteration 110: Global best score = 0.00012745796770063933
# Iteration 120: Global best score = 4.4774244841949695e-05
# Iteration 130: Global best score = 7.981328480344274e-06
# Global minimum is within epsilon 1e-06 of target at iteration 140. Stopping.
# Iteration 0: Global best score = 10.199881805263688
# Iteration 10: Global best score = 0.7511775219315031
# Iteration 20: Global best score = 0.34341818085332365
# Iteration 30: Global best score = 0.26052290404450007
# Iteration 40: Global best score = 0.21991006153920667
# Iteration 50: Global best score = 0.0072034989438276575
# Iteration 60: Global best score = 0.0023540765151435217
# Iteration 70: Global best score = 0.0011493234293848964
# Iteration 80: Global best score = 0.0010074412960290324
# Iteration 90: Global best score = 0.0007730701218169322
# Iteration 100: Global best score = 0.0004312430617514629
# Iteration 110: Global best score = 0.00019334083578970152
# Iteration 120: Global best score = 4.9655927114589105e-05
# Iteration 130: Global best score = 4.012684208465345e-06
# Iteration 140: Global best score = 1.14009656870806e-06
# Global minimum is within epsilon 1e-06 of target at iteration 142. Stopping.
# Iteration 0: Global best score = 9.87822665740124
# Iteration 10: Global best score = 0.24651973690016904
# Iteration 20: Global best score = 0.23042103592358787
# Iteration 30: Global best score = 0.19856455982686017
# Iteration 40: Global best score = 0.19856455982686017
# Iteration 50: Global best score = 0.051763549529198816
# Iteration 60: Global best score = 0.025505013220712858
# Iteration 70: Global best score = 0.006082386235256809
# Iteration 80: Global best score = 0.00174778242202267
# Iteration 90: Global best score = 0.0005624476114332033
# Iteration 100: Global best score = 0.0002370486749865286
# Iteration 110: Global best score = 2.713475363380624e-05
# Iteration 120: Global best score = 1.1078691180888e-05
# Iteration 130: Global best score = 2.3394012065303116e-06
# Global minimum is within epsilon 1e-06 of target at iteration 140. Stopping.
# Iteration 0: Global best score = 10.24372604735094
# Iteration 10: Global best score = 1.0166343778506328
# Iteration 20: Global best score = 0.7988141972785852
# Iteration 30: Global best score = 0.021759742110909475
# Iteration 40: Global best score = 0.021759742110909475
# Iteration 50: Global best score = 0.020256670408230537
# Iteration 60: Global best score = 0.015312625307153827
# Iteration 70: Global best score = 0.006590924717006619
# Iteration 80: Global best score = 0.0005793426185971562
# Iteration 90: Global best score = 0.00017254638059727156
# Iteration 100: Global best score = 0.00017254638059727156
# Iteration 110: Global best score = 4.758396748671956e-05
# Iteration 120: Global best score = 1.1359521427056762e-05
# Iteration 130: Global best score = 2.4260527280439703e-06
# Global minimum is within epsilon 1e-06 of target at iteration 136. Stopping.
# Iteration 0: Global best score = 7.2954980159363885
# Iteration 10: Global best score = 0.1580092133167459
# Iteration 20: Global best score = 0.1580092133167459
# Iteration 30: Global best score = 0.08091796439718424
# Iteration 40: Global best score = 0.06752987235640662
# Iteration 50: Global best score = 0.005967399358209224
# Iteration 60: Global best score = 0.005967399358209224
# Iteration 70: Global best score = 0.004464315503245775
# Iteration 80: Global best score = 0.0012244061190647137
# Iteration 90: Global best score = 0.000779862036747847
# Iteration 100: Global best score = 0.00011518513524011453
# Iteration 110: Global best score = 5.6381476604361325e-05
# Iteration 120: Global best score = 2.567777969364471e-06
# Iteration 130: Global best score = 2.0367392363773718e-06
# Global minimum is within epsilon 1e-06 of target at iteration 138. Stopping.
# Iteration 0: Global best score = 10.402415780092356
# Iteration 10: Global best score = 0.2951906871154759
# Iteration 20: Global best score = 0.04971783249818218
# Iteration 30: Global best score = 0.018378055372413105
# Iteration 40: Global best score = 0.018378055372413105
# Iteration 50: Global best score = 0.018378055372413105
# Iteration 60: Global best score = 0.007300863940696178
# Iteration 70: Global best score = 0.0018474377074686466
# Iteration 80: Global best score = 0.0009500166144822408
# Iteration 90: Global best score = 0.00045118565762125584
# Iteration 100: Global best score = 0.00019960826309928237
# Iteration 110: Global best score = 8.565945833982624e-06
# Iteration 120: Global best score = 6.921527433423336e-06
# Global minimum is within epsilon 1e-06 of target at iteration 128. Stopping.
# Iteration 0: Global best score = 11.436459816117289
# Iteration 10: Global best score = 0.5998097951079981
# Iteration 20: Global best score = 0.5998097951079981
# Iteration 30: Global best score = 0.09050691143358991
# Iteration 40: Global best score = 0.021568834875627108
# Iteration 50: Global best score = 0.005127750519524188
# Iteration 60: Global best score = 0.0030871331133899282
# Iteration 70: Global best score = 0.00261087859052056
# Iteration 80: Global best score = 0.0013046216190777393
# Iteration 90: Global best score = 0.0007155723068987818
# Iteration 100: Global best score = 0.00010120882874220527
# Iteration 110: Global best score = 0.00010109150195392047
# Iteration 120: Global best score = 4.308338763525654e-06
# Iteration 130: Global best score = 3.115775375039931e-06
# Global minimum is within epsilon 1e-06 of target at iteration 140. Stopping.
# Iteration 0: Global best score = 6.2361309635019815
# Iteration 10: Global best score = 0.8239876092087717
# Iteration 20: Global best score = 0.19136543328926736
# Iteration 30: Global best score = 0.19136543328926736
# Iteration 40: Global best score = 0.11102326240576632
# Iteration 50: Global best score = 0.06523611296571774
# Iteration 60: Global best score = 0.015340700354507408
# Iteration 70: Global best score = 0.00555175618160364
# Iteration 80: Global best score = 0.0040562681940383705
# Iteration 90: Global best score = 0.0007517364145503969
# Iteration 100: Global best score = 0.0003532299738897571
# Iteration 110: Global best score = 0.00014151134955442402
# Iteration 120: Global best score = 1.2417697317079757e-05
# Iteration 130: Global best score = 6.030770390186291e-06
# Iteration 140: Global best score = 3.057235542502923e-06
# Global minimum is within epsilon 1e-06 of target at iteration 145. Stopping.
# Iteration 0: Global best score = 1.5517613236684906
# Iteration 10: Global best score = 1.045494691754929
# Iteration 20: Global best score = 0.3059121467988679
# Iteration 30: Global best score = 0.1647850678651186
# Iteration 40: Global best score = 0.05423875630210562
# Iteration 50: Global best score = 0.05423875630210562
# Iteration 60: Global best score = 0.02892639328098001
# Iteration 70: Global best score = 0.02745993289972093
# Iteration 80: Global best score = 0.011612225825527123
# Iteration 90: Global best score = 0.003854215793336113
# Iteration 100: Global best score = 0.0033453495727795435
# Iteration 110: Global best score = 0.0020173352736709838
# Iteration 120: Global best score = 0.00026561493219690036
# Iteration 130: Global best score = 4.82997892814474e-05
# Iteration 140: Global best score = 3.1536795504383264e-05
# Iteration 150: Global best score = 5.033307730162306e-06
# Global minimum is within epsilon 1e-06 of target at iteration 158. Stopping.
# Iteration 0: Global best score = 3.2942201459636213
# Iteration 10: Global best score = 0.3348888329241153
# Iteration 20: Global best score = 0.3348888329241153
# Iteration 30: Global best score = 0.3348888329241153
# Iteration 40: Global best score = 0.02042372186207375
# Iteration 50: Global best score = 0.02042372186207375
# Iteration 60: Global best score = 0.02042372186207375
# Iteration 70: Global best score = 0.01933283881128789
# Iteration 80: Global best score = 0.0143000368956554
# Iteration 90: Global best score = 0.005635980308543953
# Iteration 100: Global best score = 0.0004301296427660084
# Iteration 110: Global best score = 0.0004301296427660084
# Iteration 120: Global best score = 0.00014622509885642287
# Iteration 130: Global best score = 2.137280589353807e-05
# Iteration 140: Global best score = 1.2179644088394781e-05
# Iteration 150: Global best score = 3.712512093745346e-06
# Global minimum is within epsilon 1e-06 of target at iteration 154. Stopping.
# Iteration 0: Global best score = 7.731532460912563
# Iteration 10: Global best score = 0.3630369216924092
# Iteration 20: Global best score = 0.3630369216924092
# Iteration 30: Global best score = 0.23911074318056125
# Iteration 40: Global best score = 0.22191971762375617
# Iteration 50: Global best score = 0.1717541735148882
# Iteration 60: Global best score = 0.026053992177452745
# Iteration 70: Global best score = 0.007008394800437134
# Iteration 80: Global best score = 0.004714033553277819
# Iteration 90: Global best score = 0.00019839441786873024
# Iteration 100: Global best score = 0.00019792390635275936
# Iteration 110: Global best score = 4.376842747122467e-05
# Iteration 120: Global best score = 2.2397146708375004e-05
# Iteration 130: Global best score = 8.681129135101884e-06
# Global minimum is within epsilon 1e-06 of target at iteration 139. Stopping.
# Iteration 0: Global best score = 11.086724519748335
# Iteration 10: Global best score = 0.1938787132840294
# Iteration 20: Global best score = 0.1938787132840294
# Iteration 30: Global best score = 0.1938787132840294
# Iteration 40: Global best score = 0.1377589779558055
# Iteration 50: Global best score = 0.11724858580646513
# Iteration 60: Global best score = 0.042107086661996806
# Iteration 70: Global best score = 0.0028481302312965973
# Iteration 80: Global best score = 0.0028481302312965973
# Iteration 90: Global best score = 0.0011692944289767304
# Iteration 100: Global best score = 0.00041579340536346265
# Iteration 110: Global best score = 0.00031815046804384295
# Iteration 120: Global best score = 0.00024135508109113246
# Iteration 130: Global best score = 2.6737137557297785e-06
# Iteration 140: Global best score = 2.6737137557297785e-06
# Iteration 150: Global best score = 2.6448512397969637e-06
# Global minimum is within epsilon 1e-06 of target at iteration 154. Stopping.
# Iteration 0: Global best score = 4.078058863599175
# Iteration 10: Global best score = 0.38531260907092646
# Iteration 20: Global best score = 0.34050542915575166
# Iteration 30: Global best score = 0.055339305091063995
# Iteration 40: Global best score = 0.055339305091063995
# Iteration 50: Global best score = 0.02283478581594922
# Iteration 60: Global best score = 0.0186438256571404
# Iteration 70: Global best score = 0.0009562891513970051
# Iteration 80: Global best score = 0.0009525092384206069
# Iteration 90: Global best score = 0.0009506852409093547
# Iteration 100: Global best score = 0.0009506796805145434
# Iteration 110: Global best score = 0.0005074389177868177
# Iteration 120: Global best score = 5.897700345203205e-05
# Iteration 130: Global best score = 6.283751066593624e-06
# Iteration 140: Global best score = 2.311458068948724e-06
# Global minimum is within epsilon 1e-06 of target at iteration 150. Stopping.
# Iteration 0: Global best score = 6.457175773438799
# Iteration 10: Global best score = 0.9698938452831567
# Iteration 20: Global best score = 0.33009412287514595
# Iteration 30: Global best score = 0.25372217098230765
# Iteration 40: Global best score = 0.18625173894314573
# Iteration 50: Global best score = 0.016923353926813878
# Iteration 60: Global best score = 0.016923353926813878
# Iteration 70: Global best score = 0.004444215669793028
# Iteration 80: Global best score = 0.004174162074978671
# Iteration 90: Global best score = 0.004174162074978671
# Iteration 100: Global best score = 0.003075628642204453
# Iteration 110: Global best score = 0.0015468297664544828
# Iteration 120: Global best score = 0.0004559394507102077
# Iteration 130: Global best score = 4.557968455332073e-05
# Iteration 140: Global best score = 1.1435584394536846e-05
# Global minimum is within epsilon 1e-06 of target at iteration 149. Stopping.
# Iteration 0: Global best score = 4.528882081519413
# Iteration 10: Global best score = 0.34954516069926145
# Iteration 20: Global best score = 0.1962918496289885
# Iteration 30: Global best score = 0.062140302142041026
# Iteration 40: Global best score = 0.04911152506249694
# Iteration 50: Global best score = 0.014935003784625867
# Iteration 60: Global best score = 0.003664634779621867
# Iteration 70: Global best score = 0.0029564409338012076
# Iteration 80: Global best score = 0.0006504317099182977
# Iteration 90: Global best score = 0.0005008455447286231
# Iteration 100: Global best score = 0.0002912693754244522
# Iteration 110: Global best score = 6.853508652726603e-05
# Iteration 120: Global best score = 5.01314285306087e-05
# Iteration 130: Global best score = 2.2696703414926134e-05
# Iteration 140: Global best score = 1.35855634195714e-05
# Iteration 150: Global best score = 2.196145740374078e-06
# Global minimum is within epsilon 1e-06 of target at iteration 159. Stopping.
# Iteration 0: Global best score = 9.488986885046938
# Iteration 10: Global best score = 0.5658181935244824
# Iteration 20: Global best score = 0.22920704501395806
# Iteration 30: Global best score = 0.07626431634903641
# Iteration 40: Global best score = 0.052539898431636534
# Iteration 50: Global best score = 0.022713486409668082
# Iteration 60: Global best score = 0.0013013389154505894
# Iteration 70: Global best score = 0.0007792798367778353
# Iteration 80: Global best score = 0.000716779320566463
# Iteration 90: Global best score = 0.00023812875456430405
# Iteration 100: Global best score = 5.9080319790627556e-05
# Iteration 110: Global best score = 4.1004432102642596e-05
# Iteration 120: Global best score = 1.453834903530904e-05
# Iteration 130: Global best score = 3.949137596936936e-06
# Iteration 140: Global best score = 2.1900729767487803e-06
# Global minimum is within epsilon 1e-06 of target at iteration 145. Stopping.
# Iteration 0: Global best score = 3.098968590580427
# Iteration 10: Global best score = 1.9174279882225531
# Iteration 20: Global best score = 1.3880586846924818
# Iteration 30: Global best score = 0.12967142243504215
# Iteration 40: Global best score = 0.12967142243504215
# Iteration 50: Global best score = 0.046235723123726036
# Iteration 60: Global best score = 0.012595827458146136
# Iteration 70: Global best score = 0.01056894766589922
# Iteration 80: Global best score = 0.004041501979238138
# Iteration 90: Global best score = 0.0024209209039196544
# Iteration 100: Global best score = 0.0011708456281067647
# Iteration 110: Global best score = 0.00027522169057947465
# Iteration 120: Global best score = 0.00023033891440649157
# Iteration 130: Global best score = 0.00011022389840720237
# Iteration 140: Global best score = 2.4841556229393547e-05
# Iteration 150: Global best score = 1.168104079996013e-05
# Iteration 160: Global best score = 2.111841926666358e-06
# Global minimum is within epsilon 1e-06 of target at iteration 170. Stopping.
# Iteration 0: Global best score = 2.7717543483847717
# Iteration 10: Global best score = 0.5659904086850749
# Iteration 20: Global best score = 0.17140581426216217
# Iteration 30: Global best score = 0.04664186441704077
# Iteration 40: Global best score = 0.03488137456043505
# Iteration 50: Global best score = 0.032328431633903865
# Iteration 60: Global best score = 0.030880155825503852
# Iteration 70: Global best score = 0.007623494569874101
# Iteration 80: Global best score = 0.0022647931829529178
# Iteration 90: Global best score = 0.0009338078333702704
# Iteration 100: Global best score = 0.00013320716552955858
# Iteration 110: Global best score = 3.184528606370307e-05
# Iteration 120: Global best score = 2.699592281674157e-05
# Iteration 130: Global best score = 1.0128648704199605e-05
# Iteration 140: Global best score = 3.7490886346525087e-06
# Global minimum is within epsilon 1e-06 of target at iteration 147. Stopping.
# Iteration 0: Global best score = 6.203590718873738
# Iteration 10: Global best score = 1.363860605573184
# Iteration 20: Global best score = 1.363860605573184
# Iteration 30: Global best score = 0.27583798135263793
# Iteration 40: Global best score = 0.27583798135263793
# Iteration 50: Global best score = 0.27583798135263793
# Iteration 60: Global best score = 0.06775383422447279
# Iteration 70: Global best score = 0.007567199619622489
# Iteration 80: Global best score = 0.007567199619622489
# Iteration 90: Global best score = 0.004645098831851602
# Iteration 100: Global best score = 0.0020177429147065773
# Iteration 110: Global best score = 0.0008306576233825247
# Iteration 120: Global best score = 7.990093986665059e-05
# Iteration 130: Global best score = 7.990093986665059e-05
# Iteration 140: Global best score = 7.990093986665059e-05
# Iteration 150: Global best score = 1.9823076894187608e-05
# Iteration 160: Global best score = 9.640187944359724e-06
# Iteration 170: Global best score = 3.5768717698836383e-06
# Global minimum is within epsilon 1e-06 of target at iteration 177. Stopping.
# Iteration 0: Global best score = 8.777256632439903
# Iteration 10: Global best score = 0.9904200850352756
# Iteration 20: Global best score = 0.3662657214721574
# Iteration 30: Global best score = 0.33145724704087387
# Iteration 40: Global best score = 0.035514665364481335
# Iteration 50: Global best score = 0.035514665364481335
# Iteration 60: Global best score = 0.035514665364481335
# Iteration 70: Global best score = 0.035514665364481335
# Iteration 80: Global best score = 0.032269483117815856
# Iteration 90: Global best score = 0.01159739520866454
# Iteration 100: Global best score = 0.005870121752419966
# Iteration 110: Global best score = 0.0010996484348528845
# Iteration 120: Global best score = 0.0006324384861682297
# Iteration 130: Global best score = 0.0004605967036970249
# Iteration 140: Global best score = 6.109936547860073e-05
# Iteration 150: Global best score = 3.448093915325856e-05
# Iteration 160: Global best score = 5.923449752476273e-06
# Global minimum is within epsilon 1e-06 of target at iteration 167. Stopping.
# Iteration 0: Global best score = 6.857031240853145
# Iteration 10: Global best score = 2.8230365224872895
# Iteration 20: Global best score = 0.5086379114947381
# Iteration 30: Global best score = 0.28751599159776875
# Iteration 40: Global best score = 0.28751599159776875
# Iteration 50: Global best score = 0.19483926122713457
# Iteration 60: Global best score = 0.11349702027752473
# Iteration 70: Global best score = 0.10896487925362708
# Iteration 80: Global best score = 0.10881261646935458
# Iteration 90: Global best score = 0.030338266870526542
# Iteration 100: Global best score = 0.011459042703283462
# Iteration 110: Global best score = 0.0061721972967778704
# Iteration 120: Global best score = 0.0024278604651617464
# Iteration 130: Global best score = 0.0002809115575321819
# Iteration 140: Global best score = 6.42832960910944e-05
# Iteration 150: Global best score = 3.3448468351071625e-05
# Iteration 160: Global best score = 2.2425508916956716e-05
# Iteration 170: Global best score = 3.096534325397471e-06
# Iteration 180: Global best score = 1.0084583625946664e-06
# Global minimum is within epsilon 1e-06 of target at iteration 187. Stopping.
# Iteration 0: Global best score = 11.006875629335864
# Iteration 10: Global best score = 1.5914777444648291
# Iteration 20: Global best score = 1.2292099731041266
# Iteration 30: Global best score = 1.1239849433310423
# Iteration 40: Global best score = 0.05784995961796158
# Iteration 50: Global best score = 0.05784995961796158
# Iteration 60: Global best score = 0.04046572935651627
# Iteration 70: Global best score = 0.04046572935651627
# Iteration 80: Global best score = 0.0052319467539381215
# Iteration 90: Global best score = 0.0026245465480454477
# Iteration 100: Global best score = 0.0026245465480454477
# Iteration 110: Global best score = 0.0011388608935445355
# Iteration 120: Global best score = 0.0003750487919593759
# Iteration 130: Global best score = 0.00032506455356839936
# Iteration 140: Global best score = 0.00011474414884249384
# Iteration 150: Global best score = 4.345018937090828e-06
# Iteration 160: Global best score = 2.6309221508036273e-06
# Iteration 170: Global best score = 1.0496782967273077e-06
# Global minimum is within epsilon 1e-06 of target at iteration 172. Stopping.
# Iteration 0: Global best score = 4.94004401850809
# Iteration 10: Global best score = 0.31144483279375423
# Iteration 20: Global best score = 0.31144483279375423
# Iteration 30: Global best score = 0.12458221116854462
# Iteration 40: Global best score = 0.0727183094581183
# Iteration 50: Global best score = 0.015392696787195792
# Iteration 60: Global best score = 0.014934726649127317
# Iteration 70: Global best score = 0.011501255309010805
# Iteration 80: Global best score = 0.011501255309010805
# Iteration 90: Global best score = 0.006590594100878366
# Iteration 100: Global best score = 0.0027013080302613623
# Iteration 110: Global best score = 0.001006624767736941
# Iteration 120: Global best score = 0.00025018298962153906
# Iteration 130: Global best score = 0.0001295638870328908
# Iteration 140: Global best score = 9.441379575081399e-05
# Iteration 150: Global best score = 1.911792309572391e-05
# Iteration 160: Global best score = 3.057563205732805e-06
# Iteration 170: Global best score = 1.3554059852260991e-06
# Global minimum is within epsilon 1e-06 of target at iteration 171. Stopping.
# Iteration 0: Global best score = 6.820455351014418
# Iteration 10: Global best score = 0.6544456604891846
# Iteration 20: Global best score = 0.1550196844266165
# Iteration 30: Global best score = 0.1550196844266165
# Iteration 40: Global best score = 0.1550196844266165
# Iteration 50: Global best score = 0.08196985617826558
# Iteration 60: Global best score = 0.02748002096375446
# Iteration 70: Global best score = 0.011266700362551507
# Iteration 80: Global best score = 0.011266700362551507
# Iteration 90: Global best score = 0.008117126296700139
# Iteration 100: Global best score = 0.005219900205358119
# Iteration 110: Global best score = 0.0038003383808313806
# Iteration 120: Global best score = 0.0008479734598556554
# Iteration 130: Global best score = 0.0004392346920956136
# Iteration 140: Global best score = 5.8959194686458716e-06
# Iteration 150: Global best score = 3.207587856213223e-06
# Iteration 160: Global best score = 1.2061504688354319e-06
# Global minimum is within epsilon 1e-06 of target at iteration 166. Stopping.
# Iteration 0: Global best score = 6.497296178071839
# Iteration 10: Global best score = 2.9667129219402253
# Iteration 20: Global best score = 0.3896083369679215
# Iteration 30: Global best score = 0.3896083369679215
# Iteration 40: Global best score = 0.3896083369679215
# Iteration 50: Global best score = 0.10200902022469949
# Iteration 60: Global best score = 0.08746034661229318
# Iteration 70: Global best score = 0.0329273281973923
# Iteration 80: Global best score = 0.005918436973545216
# Iteration 90: Global best score = 0.004216312094634578
# Iteration 100: Global best score = 0.0016496873688862657
# Iteration 110: Global best score = 0.0006216356398920375
# Iteration 120: Global best score = 0.0006216356398920375
# Iteration 130: Global best score = 0.000362721016799572
# Iteration 140: Global best score = 1.530317062092834e-05
# Iteration 150: Global best score = 1.530317062092834e-05
# Global minimum is within epsilon 1e-06 of target at iteration 160. Stopping.
# Iteration 0: Global best score = 4.487121329318832
# Iteration 10: Global best score = 0.07249049903508409
# Iteration 20: Global best score = 0.07249049903508409
# Iteration 30: Global best score = 0.07249049903508409
# Iteration 40: Global best score = 0.07249049903508409
# Iteration 50: Global best score = 0.07249049903508409
# Iteration 60: Global best score = 0.07249049903508409
# Iteration 70: Global best score = 0.024838536194085936
# Iteration 80: Global best score = 0.009375986712122586
# Iteration 90: Global best score = 0.00448299826123888
# Iteration 100: Global best score = 0.00448299826123888
# Iteration 110: Global best score = 0.0036061071412523127
# Iteration 120: Global best score = 0.002297833124125237
# Iteration 130: Global best score = 5.1667097406227214e-05
# Iteration 140: Global best score = 5.1667097406227214e-05
# Iteration 150: Global best score = 1.807080828841734e-05
# Iteration 160: Global best score = 1.0626694525672775e-05
# Iteration 170: Global best score = 5.815130244446465e-06
# Iteration 180: Global best score = 2.419491746952218e-06
# Global minimum is within epsilon 1e-06 of target at iteration 184. Stopping.
# Iteration 0: Global best score = 4.523411186735263
# Iteration 10: Global best score = 1.9029651348250352
# Iteration 20: Global best score = 0.08992617782060863
# Iteration 30: Global best score = 0.08992617782060863
# Iteration 40: Global best score = 0.08992617782060863
# Iteration 50: Global best score = 0.04793462861693287
# Iteration 60: Global best score = 0.03818765979159666
# Iteration 70: Global best score = 0.013415055359236039
# Iteration 80: Global best score = 0.003856551116439011
# Iteration 90: Global best score = 0.003790195856403944
# Iteration 100: Global best score = 0.003790195856403944
# Iteration 110: Global best score = 0.0006847130992047035
# Iteration 120: Global best score = 9.185534068167911e-05
# Iteration 130: Global best score = 1.477696901419634e-05
# Iteration 140: Global best score = 7.065934874095348e-06
# Iteration 150: Global best score = 7.034039903874856e-06
# Global minimum is within epsilon 1e-06 of target at iteration 160. Stopping.
# Iteration 0: Global best score = 3.659042544346786
# Iteration 10: Global best score = 2.258692772103299
# Iteration 20: Global best score = 1.0337146544399478
# Iteration 30: Global best score = 0.43427063392998067
# Iteration 40: Global best score = 0.08383931439951597
# Iteration 50: Global best score = 0.08383931439951597
# Iteration 60: Global best score = 0.05019606558135736
# Iteration 70: Global best score = 0.05019606558135736
# Iteration 80: Global best score = 0.0186854344520353
# Iteration 90: Global best score = 0.0186854344520353
# Iteration 100: Global best score = 0.005110106180805207
# Iteration 110: Global best score = 0.0014240827401335032
# Iteration 120: Global best score = 0.0014240827401335032
# Iteration 130: Global best score = 0.00025242736921571307
# Iteration 140: Global best score = 0.00021486202241804975
# Iteration 150: Global best score = 4.835646479195432e-05
# Iteration 160: Global best score = 3.340494519665782e-06
# Iteration 170: Global best score = 1.436011168198803e-06
# Global minimum is within epsilon 1e-06 of target at iteration 171. Stopping.
# Iteration 0: Global best score = 9.46609484830655
# Iteration 10: Global best score = 0.24825509747852736
# Iteration 20: Global best score = 0.12952256731247802
# Iteration 30: Global best score = 0.09786007247020523
# Iteration 40: Global best score = 0.012808519856097877
# Iteration 50: Global best score = 0.012808519856097877
# Iteration 60: Global best score = 0.009096450199127748
# Iteration 70: Global best score = 0.007083325288832487
# Iteration 80: Global best score = 0.006080984650865151
# Iteration 90: Global best score = 0.0004242304435178035
# Iteration 100: Global best score = 8.722911334091421e-05
# Iteration 110: Global best score = 8.97954556622338e-06
# Iteration 120: Global best score = 8.4633600683226e-06
# Global minimum is within epsilon 1e-06 of target at iteration 130. Stopping.
# Iteration 0: Global best score = 10.751897159352405
# Iteration 10: Global best score = 1.148388569242535
# Iteration 20: Global best score = 0.6298542496943509
# Iteration 30: Global best score = 0.24536717085923998
# Iteration 40: Global best score = 0.029554546138392812
# Iteration 50: Global best score = 0.013314740274875891
# Iteration 60: Global best score = 0.009944444217265147
# Iteration 70: Global best score = 0.00262678532076821
# Iteration 80: Global best score = 0.0009495532419916408
# Iteration 90: Global best score = 4.0694478649516697e-05
# Iteration 100: Global best score = 4.0694478649516697e-05
# Iteration 110: Global best score = 1.749547598750567e-05
# Iteration 120: Global best score = 1.743904433171295e-05
# Iteration 130: Global best score = 6.418242123107376e-06
# Iteration 140: Global best score = 1.158361140785047e-06
# Global minimum is within epsilon 1e-06 of target at iteration 141. Stopping.
# Iteration 0: Global best score = 9.571578939585395
# Iteration 10: Global best score = 0.36784381744909966
# Iteration 20: Global best score = 0.35628704399871625
# Iteration 30: Global best score = 0.0960077519994198
# Iteration 40: Global best score = 0.010446949637405556
# Iteration 50: Global best score = 0.004381611665458696
# Iteration 60: Global best score = 0.004381611665458696
# Iteration 70: Global best score = 0.002211517449624001
# Iteration 80: Global best score = 0.00019351787882060378
# Iteration 90: Global best score = 0.0001198361940386583
# Iteration 100: Global best score = 7.13703672414745e-05
# Iteration 110: Global best score = 3.391721222145705e-05
# Iteration 120: Global best score = 5.830519701266468e-06
# Iteration 130: Global best score = 3.681844429781478e-06
# Global minimum is within epsilon 1e-06 of target at iteration 135. Stopping.
# Iteration 0: Global best score = 11.277824665473346
# Iteration 10: Global best score = 0.3384609727819812
# Iteration 20: Global best score = 0.09222286676830693
# Iteration 30: Global best score = 0.09222286676830693
# Iteration 40: Global best score = 0.021707725791618504
# Iteration 50: Global best score = 0.021707725791618504
# Iteration 60: Global best score = 0.008407799429349883
# Iteration 70: Global best score = 0.006923791032829474
# Iteration 80: Global best score = 0.0007892631037162978
# Iteration 90: Global best score = 0.0007892631037162978
# Iteration 100: Global best score = 0.0003732581781190625
# Iteration 110: Global best score = 3.697328229579355e-05
# Iteration 120: Global best score = 1.2866117740095717e-06
# Global minimum is within epsilon 1e-06 of target at iteration 126. Stopping.
# Iteration 0: Global best score = 11.815755275736118
# Iteration 10: Global best score = 0.43987624917833346
# Iteration 20: Global best score = 0.1210082890265487
# Iteration 30: Global best score = 0.10727998251848847
# Iteration 40: Global best score = 0.08878857643954108
# Iteration 50: Global best score = 0.0629761311058954
# Iteration 60: Global best score = 0.04200871355542235
# Iteration 70: Global best score = 0.01607149311684397
# Iteration 80: Global best score = 0.0006944523589749174
# Iteration 90: Global best score = 3.1585156218927324e-05
# Iteration 100: Global best score = 1.2141669938348087e-05
# Global minimum is within epsilon 1e-06 of target at iteration 109. Stopping.
# Iteration 0: Global best score = 10.342686296490921
# Iteration 10: Global best score = 1.6791767112483424
# Iteration 20: Global best score = 0.48110210301019807
# Iteration 30: Global best score = 0.48110210301019807
# Iteration 40: Global best score = 0.10476890335276723
# Iteration 50: Global best score = 0.07237515266910721
# Iteration 60: Global best score = 0.06485204388444332
# Iteration 70: Global best score = 0.0024363024640092767
# Iteration 80: Global best score = 0.0006871130623804511
# Iteration 90: Global best score = 0.00022354639083888017
# Iteration 100: Global best score = 7.194526946507906e-05
# Iteration 110: Global best score = 1.7662522261208125e-05
# Global minimum is within epsilon 1e-06 of target at iteration 117. Stopping.
# Iteration 0: Global best score = 10.380082949412321
# Iteration 10: Global best score = 1.279113560197882
# Iteration 20: Global best score = 0.1527281507734881
# Iteration 30: Global best score = 0.03866324371987462
# Iteration 40: Global best score = 0.008583180612494079
# Iteration 50: Global best score = 0.00414418191048016
# Iteration 60: Global best score = 0.00330600220572963
# Iteration 70: Global best score = 0.00047757906720180543
# Iteration 80: Global best score = 0.00042459984486287183
# Iteration 90: Global best score = 0.00010402322726266178
# Iteration 100: Global best score = 3.458595428584843e-05
# Iteration 110: Global best score = 9.293850855573993e-06
# Iteration 120: Global best score = 2.6231674010723793e-06
# Global minimum is within epsilon 1e-06 of target at iteration 127. Stopping.
# Iteration 0: Global best score = 10.834879215904264
# Iteration 10: Global best score = 0.5095258552585205
# Iteration 20: Global best score = 0.1180809482512406
# Iteration 30: Global best score = 0.10625189823997205
# Iteration 40: Global best score = 0.09215178574435656
# Iteration 50: Global best score = 0.017917570848350994
# Iteration 60: Global best score = 0.01668295413979992
# Iteration 70: Global best score = 0.013909693184779304
# Iteration 80: Global best score = 0.006446389809113828
# Iteration 90: Global best score = 0.002935236706676836
# Iteration 100: Global best score = 0.00010285221062789063
# Iteration 110: Global best score = 3.856326505813357e-05
# Iteration 120: Global best score = 3.744252286441707e-06
# Global minimum is within epsilon 1e-06 of target at iteration 128. Stopping.
# Iteration 0: Global best score = 9.50297104075113
# Iteration 10: Global best score = 1.5967486677547638
# Iteration 20: Global best score = 0.47427667808714036
# Iteration 30: Global best score = 0.1819292515481199
# Iteration 40: Global best score = 0.0157158128791548
# Iteration 50: Global best score = 0.0011967127254632892
# Iteration 60: Global best score = 0.0008814842957218794
# Iteration 70: Global best score = 0.0008814842957218794
# Iteration 80: Global best score = 0.0008814842957218794
# Iteration 90: Global best score = 0.00044388743233669814
# Iteration 100: Global best score = 0.00020846027698029346
# Iteration 110: Global best score = 0.00017201021350077284
# Iteration 120: Global best score = 2.7297160482664395e-05
# Iteration 130: Global best score = 1.8418902958394767e-06
# Global minimum is within epsilon 1e-06 of target at iteration 138. Stopping.
# Iteration 0: Global best score = 11.355448556344921
# Iteration 10: Global best score = 1.817768498271033
# Iteration 20: Global best score = 1.769564848056579
# Iteration 30: Global best score = 1.6439005202347698
# Iteration 40: Global best score = 0.03318796741567498
# Iteration 50: Global best score = 0.030100376607884005
# Iteration 60: Global best score = 0.012388820679842372
# Iteration 70: Global best score = 0.0049468461247355044
# Iteration 80: Global best score = 0.0039029889250739025
# Iteration 90: Global best score = 0.0011072872474469087
# Iteration 100: Global best score = 0.00016890505687827684
# Iteration 110: Global best score = 0.0001688592993827065
# Iteration 120: Global best score = 1.670269200504393e-05
# Global minimum is within epsilon 1e-06 of target at iteration 122. Stopping.
# Iteration 0: Global best score = 8.527891872350626
# Iteration 10: Global best score = 1.8136782679886676
# Iteration 20: Global best score = 1.7083474683560174
# Iteration 30: Global best score = 1.5336427293549488
# Iteration 40: Global best score = 0.07028489443441943
# Iteration 50: Global best score = 0.022774233161531487
# Iteration 60: Global best score = 0.014095894011824317
# Iteration 70: Global best score = 0.0029609574044831
# Iteration 80: Global best score = 0.0024949305762977936
# Iteration 90: Global best score = 0.0009053311666602504
# Iteration 100: Global best score = 0.00013959140865127395
# Iteration 110: Global best score = 4.5482982248490345e-05
# Iteration 120: Global best score = 3.5051722861556556e-05
# Iteration 130: Global best score = 7.13809533126053e-06
# Iteration 140: Global best score = 7.13809533126053e-06
# Global minimum is within epsilon 1e-06 of target at iteration 149. Stopping.
# Iteration 0: Global best score = 11.565613706259466
# Iteration 10: Global best score = 2.642781443378166
# Iteration 20: Global best score = 2.59658737094118
# Iteration 30: Global best score = 2.582121699972682
# Iteration 40: Global best score = 2.580028738727077
# Iteration 50: Global best score = 0.10772471753544055
# Iteration 60: Global best score = 0.00896330257503708
# Iteration 70: Global best score = 0.0018338785175875394
# Iteration 80: Global best score = 0.0018338785175875394
# Iteration 90: Global best score = 0.0011491663401490548
# Iteration 100: Global best score = 0.00018497215975843417
# Iteration 110: Global best score = 2.9639306820872235e-05
# Iteration 120: Global best score = 1.4332811908435161e-05
# Iteration 130: Global best score = 4.797891115959629e-06
# Global minimum is within epsilon 1e-06 of target at iteration 134. Stopping.
# Iteration 0: Global best score = 10.209827162098883
# Iteration 10: Global best score = 2.6889249486222018
# Iteration 20: Global best score = 2.0887383985660404
# Iteration 30: Global best score = 0.6207251864550511
# Iteration 40: Global best score = 0.046575035462379066
# Iteration 50: Global best score = 0.017494850816227814
# Iteration 60: Global best score = 0.011835429360591565
# Iteration 70: Global best score = 0.0002447009840946812
# Iteration 80: Global best score = 0.0002447009840946812
# Iteration 90: Global best score = 0.00022793280928512516
# Iteration 100: Global best score = 0.00016488291519367593
# Iteration 110: Global best score = 5.3576154631418405e-05
# Iteration 120: Global best score = 1.0652501668761971e-05
# Global minimum is within epsilon 1e-06 of target at iteration 130. Stopping.
# Iteration 0: Global best score = 8.498087181078922
# Iteration 10: Global best score = 0.6000317610196935
# Iteration 20: Global best score = 0.07017064043565258
# Iteration 30: Global best score = 0.07017064043565258
# Iteration 40: Global best score = 0.07017064043565258
# Iteration 50: Global best score = 0.06232869423176668
# Iteration 60: Global best score = 0.0242004212947049
# Iteration 70: Global best score = 0.005795558154123359
# Iteration 80: Global best score = 0.0007028297339428669
# Iteration 90: Global best score = 0.00018288142029776466
# Iteration 100: Global best score = 0.0001070848685533754
# Iteration 110: Global best score = 4.411677896998256e-05
# Iteration 120: Global best score = 2.164841710028398e-05
# Iteration 130: Global best score = 9.487742304248314e-06
# ...
# Iteration 30: Global best score = -78.3285145788899
# Target global minimum -78.33198 reached at iteration 35. Stopping.
# Iteration 0: Global best score = -64.05605659890807
# Iteration 10: Global best score = -78.2893009988724
# Iteration 20: Global best score = -78.2893009988724
# Iteration 30: Global best score = -78.33098322077859
# Iteration 40: Global best score = -78.33098322077859
# Iteration 50: Global best score = -78.33149339363555
# Iteration 60: Global best score = -78.33183128626186
# Target global minimum -78.33198 reached at iteration 62. Stopping.
# Iteration 0: Global best score = -63.6216022915014
# Iteration 10: Global best score = -78.29710955057567
# Iteration 20: Global best score = -78.32437210308805
# Iteration 30: Global best score = -78.32600974416744
# Target global minimum -78.33198 reached at iteration 34. Stopping.
# Iteration 0: Global best score = -63.911558524504954
# Iteration 10: Global best score = -78.32228010009095
# Iteration 20: Global best score = -78.32228010009095
# Iteration 30: Global best score = -78.33194632521926
# Target global minimum -78.33198 reached at iteration 38. Stopping.
# Iteration 0: Global best score = -64.03420867320611
# Iteration 10: Global best score = -78.32952134128038
# Iteration 20: Global best score = -78.3307598690713
# Iteration 30: Global best score = -78.3307598690713
# Target global minimum -78.33198 reached at iteration 40. Stopping.
# Iteration 0: Global best score = -63.84299298430745
# Iteration 10: Global best score = -78.27606590916487
# Iteration 20: Global best score = -78.30694719976833
# Iteration 30: Global best score = -78.33172649995524
# Iteration 40: Global best score = -78.33196404577274
# Iteration 50: Global best score = -78.33196404577274
# Target global minimum -78.33198 reached at iteration 51. Stopping.
# Iteration 0: Global best score = -64.15315879614325
# Iteration 10: Global best score = -78.25820391127277
# Iteration 20: Global best score = -78.33143443017474
# Iteration 30: Global best score = -78.33166569158828
# Iteration 40: Global best score = -78.33166569158828
# Iteration 50: Global best score = -78.33192648697688
# Global minimum is within epsilon 1e-06 of target at iteration 55. Stopping.
# Iteration 0: Global best score = -62.83786905324581
# Iteration 10: Global best score = -78.3204225872219
# Iteration 20: Global best score = -78.32259326165811
# Iteration 30: Global best score = -78.33002169829368
# Iteration 40: Global best score = -78.33130642678994
# Iteration 50: Global best score = -78.33196404346475
# Target global minimum -78.33198 reached at iteration 59. Stopping.
# Iteration 0: Global best score = -64.1384665604867
# Iteration 10: Global best score = -78.0804171700388
# Iteration 20: Global best score = -78.33102647963663
# Iteration 30: Global best score = -78.33102647963663
# Iteration 40: Global best score = -78.33144199887471
# Target global minimum -78.33198 reached at iteration 45. Stopping.
# Iteration 0: Global best score = -64.03772369859222
# Iteration 10: Global best score = -64.4855141904954
# Iteration 20: Global best score = -78.309292495421
# Iteration 30: Global best score = -78.309292495421
# Iteration 40: Global best score = -78.32897222776495
# Target global minimum -78.33198 reached at iteration 45. Stopping.
# Iteration 0: Global best score = -63.018624220488604
# Iteration 10: Global best score = -78.31359965022477
# Iteration 20: Global best score = -78.32050444477511
# Target global minimum -78.33198 reached at iteration 28. Stopping.
# Iteration 0: Global best score = -63.88822319484861
# Iteration 10: Global best score = -78.13044427942839
# Iteration 20: Global best score = -78.33136924988627
# Iteration 30: Global best score = -78.33136924988627
# Target global minimum -78.33198 reached at iteration 40. Stopping.
# Iteration 0: Global best score = -62.902645569293824
# Iteration 10: Global best score = -78.33090011608337
# Iteration 20: Global best score = -78.33090011608337
# Iteration 30: Global best score = -78.33097651299155
# Target global minimum -78.33198 reached at iteration 34. Stopping.
# Iteration 0: Global best score = -63.98419548262524
# Iteration 10: Global best score = -77.82393417548482
# Iteration 20: Global best score = -78.29266162156611
# Iteration 30: Global best score = -78.30893282896602
# Iteration 40: Global best score = -78.33191362919696
# Target global minimum -78.33198 reached at iteration 42. Stopping.
# Iteration 0: Global best score = -64.15597124331087
# Iteration 10: Global best score = -78.27230941908414
# Iteration 20: Global best score = -78.3157434084076
# Iteration 30: Global best score = -78.32877510354086
# Iteration 40: Global best score = -78.33195930480149
# Target global minimum -78.33198 reached at iteration 50. Stopping.
# Iteration 0: Global best score = -63.63266907321237
# Iteration 10: Global best score = -78.28969243389012
# Iteration 20: Global best score = -78.32356247247037
# Iteration 30: Global best score = -78.33062611425692
# Iteration 40: Global best score = -78.33195455303878
# Target global minimum -78.33198 reached at iteration 41. Stopping.
# Iteration 0: Global best score = -63.734098791247575
# Iteration 10: Global best score = -78.23476446855625
# Iteration 20: Global best score = -78.31046719337186
# Iteration 30: Global best score = -78.31650587545909
# Iteration 40: Global best score = -78.3296405131351
# Iteration 50: Global best score = -78.33183401398493
# Target global minimum -78.33198 reached at iteration 51. Stopping.
# Iteration 0: Global best score = -63.438820880932795
# Iteration 10: Global best score = -78.10571170267443
# Iteration 20: Global best score = -78.32896598577388
# Iteration 30: Global best score = -78.32896598577388
# Target global minimum -78.33198 reached at iteration 39. Stopping.
# Iteration 0: Global best score = -63.17843330688184
# Iteration 10: Global best score = -74.24344777727859
# Iteration 20: Global best score = -78.29824755302272
# Iteration 30: Global best score = -78.33167631284866
# Iteration 40: Global best score = -78.33196770003741
# Target global minimum -78.33198 reached at iteration 50. Stopping.
# Iteration 0: Global best score = -63.807356452633115
# Iteration 10: Global best score = -78.23953213160755
# Iteration 20: Global best score = -78.31252515450014
# Iteration 30: Global best score = -78.32800772777813
# Iteration 40: Global best score = -78.33123080798327
# Target global minimum -78.33198 reached at iteration 43. Stopping.
# Iteration 0: Global best score = -64.1845932436435
# Iteration 10: Global best score = -78.33107981740847
# Iteration 20: Global best score = -78.33124019044465
# Target global minimum -78.33198 reached at iteration 26. Stopping.
# Iteration 0: Global best score = -64.11621787890543
# Iteration 10: Global best score = -78.3154070762673
# Iteration 20: Global best score = -78.31781140436955
# Iteration 30: Global best score = -78.31781140436955
# Iteration 40: Global best score = -78.33194741944547
# Target global minimum -78.33198 reached at iteration 42. Stopping.
# Iteration 0: Global best score = -63.85998298277774
# Iteration 10: Global best score = -78.32038953574343
# Iteration 20: Global best score = -78.32038953574343
# Target global minimum -78.33198 reached at iteration 28. Stopping.
# Iteration 0: Global best score = -63.96082291648491
# Iteration 10: Global best score = -78.32461979237179
# Iteration 20: Global best score = -78.32461979237179
# Iteration 30: Global best score = -78.32696122766482
# Iteration 40: Global best score = -78.33187591812666
# Target global minimum -78.33198 reached at iteration 44. Stopping.
# Iteration 0: Global best score = -64.06612851212677
# Iteration 10: Global best score = -78.3209210732671
# Iteration 20: Global best score = -78.32829679212125
# Target global minimum -78.33198 reached at iteration 24. Stopping.
# Iteration 0: Global best score = -64.0090504548658
# Iteration 10: Global best score = -78.33005236915083
# Iteration 20: Global best score = -78.33047313711768
# Target global minimum -78.33198 reached at iteration 24. Stopping.
# Iteration 0: Global best score = -63.94367588016304
# Iteration 10: Global best score = -78.22325693057925
# Iteration 20: Global best score = -78.30177145495975
# Iteration 30: Global best score = -78.331320137101
# Iteration 40: Global best score = -78.331320137101
# Target global minimum -78.33198 reached at iteration 43. Stopping.
# Iteration 0: Global best score = -63.674727943787595
# Iteration 10: Global best score = -78.18912172878517
# Iteration 20: Global best score = -78.3305486535092
# Target global minimum -78.33198 reached at iteration 24. Stopping.
# Iteration 0: Global best score = -63.534461230043846
# Iteration 10: Global best score = -78.29487073090708
# Iteration 20: Global best score = -78.33146486984708
# Target global minimum -78.33198 reached at iteration 21. Stopping.
# Iteration 0: Global best score = -64.1790472122235
# Iteration 10: Global best score = -78.16396010265836
# Iteration 20: Global best score = -78.32495333058162
# Iteration 30: Global best score = -78.33088338638682
# Target global minimum -78.33198 reached at iteration 33. Stopping.
# Iteration 0: Global best score = -62.54375045172847
# Iteration 10: Global best score = -78.31267778796916
# Iteration 20: Global best score = -78.32850285088605
# Iteration 30: Global best score = -78.32850285088605
# Iteration 40: Global best score = -78.33002736529204
# Target global minimum -78.33198 reached at iteration 42. Stopping.
# Iteration 0: Global best score = -63.92475214034971
# Iteration 10: Global best score = -78.2207303314795
# Iteration 20: Global best score = -78.32838760260861
# Iteration 30: Global best score = -78.33115759923504
# Target global minimum -78.33198 reached at iteration 31. Stopping.
# Iteration 0: Global best score = -64.059133936277
# Iteration 10: Global best score = -78.31260439469108
# Iteration 20: Global best score = -78.31260439469108
# Target global minimum -78.33198 reached at iteration 22. Stopping.
# Iteration 0: Global best score = -63.90336435095748
# Iteration 10: Global best score = -78.32293528259372
# Iteration 20: Global best score = -78.32683452895833
# Iteration 30: Global best score = -78.32962598766653
# Iteration 40: Global best score = -78.33135267305923
# Target global minimum -78.33198 reached at iteration 47. Stopping.
# Iteration 0: Global best score = -63.90440033671985
# Iteration 10: Global best score = -78.28034051589614
# Iteration 20: Global best score = -78.28789137447748
# Iteration 30: Global best score = -78.31169286805364
# Iteration 40: Global best score = -78.33024585925224
# Iteration 50: Global best score = -78.33179274012683
# Target global minimum -78.33198 reached at iteration 56. Stopping.
# Iteration 0: Global best score = -63.72993122670577
# Iteration 10: Global best score = -78.11732964712711
# Iteration 20: Global best score = -78.31063723737017
# Iteration 30: Global best score = -78.31063723737017
# Iteration 40: Global best score = -78.32893538460067
# Iteration 50: Global best score = -78.3307970295624
# Iteration 60: Global best score = -78.33135517166548
# Target global minimum -78.33198 reached at iteration 64. Stopping.
# Iteration 0: Global best score = -64.08446188473594
# Iteration 10: Global best score = -78.2258197876615
# Iteration 20: Global best score = -78.32619783781097
# Iteration 30: Global best score = -78.33194119089148
# Iteration 40: Global best score = -78.33194119089148
# Target global minimum -78.33198 reached at iteration 49. Stopping.
# Iteration 0: Global best score = -63.50721077403551
# Iteration 10: Global best score = -78.27333166284248
# Iteration 20: Global best score = -78.32618606388328
# Iteration 30: Global best score = -78.32618606388328
# Iteration 40: Global best score = -78.33172028670052
# Iteration 50: Global best score = -78.33172028670052
# Global minimum is within epsilon 1e-06 of target at iteration 54. Stopping.
# Iteration 0: Global best score = -63.95497181321939
# Iteration 10: Global best score = -78.30020879521338
# Iteration 20: Global best score = -78.3133245820014
# Iteration 30: Global best score = -78.32941810877192
# Iteration 40: Global best score = -78.32941810877192
# Target global minimum -78.33198 reached at iteration 49. Stopping.
# Iteration 0: Global best score = -63.00540103828956
# Iteration 10: Global best score = -78.32294647595249
# Iteration 20: Global best score = -78.32316718185871
# Iteration 30: Global best score = -78.3294819701791
# Iteration 40: Global best score = -78.3294819701791
# Iteration 50: Global best score = -78.3294819701791
# Iteration 60: Global best score = -78.33042477959611
# Target global minimum -78.33198 reached at iteration 67. Stopping.
# Iteration 0: Global best score = -64.19324064800605
# Iteration 10: Global best score = -77.91534994616174
# Iteration 20: Global best score = -78.31897488142388
# Iteration 30: Global best score = -78.3262102897666
# Iteration 40: Global best score = -78.33004706088235
# Target global minimum -78.33198 reached at iteration 50. Stopping.
# Iteration 0: Global best score = -77.76732178498418
# Iteration 10: Global best score = -78.04590646462408
# Iteration 20: Global best score = -78.30554033049975
# Iteration 30: Global best score = -78.32601803526782
# Iteration 40: Global best score = -78.32601803526782
# Iteration 50: Global best score = -78.32919648785365
# Target global minimum -78.33198 reached at iteration 54. Stopping.
# Iteration 0: Global best score = -64.02620409737209
# Iteration 10: Global best score = -78.22269026343773
# Iteration 20: Global best score = -78.25479391025635
# Iteration 30: Global best score = -78.3319287920948
# Target global minimum -78.33198 reached at iteration 38. Stopping.
# Iteration 0: Global best score = -64.13485056972898
# Iteration 10: Global best score = -78.26171597533062
# Iteration 20: Global best score = -78.26302157578422
# Iteration 30: Global best score = -78.26302157578422
# Iteration 40: Global best score = -78.32922282389646
# Iteration 50: Global best score = -78.32922282389646
# Iteration 60: Global best score = -78.33035975703535
# Iteration 70: Global best score = -78.33194288678268
# Iteration 80: Global best score = -78.33194288678268
# Target global minimum -78.33198 reached at iteration 85. Stopping.
# Iteration 0: Global best score = -64.0706886066646
# Iteration 10: Global best score = -78.29185571204435
# Iteration 20: Global best score = -78.33072522092678
# Iteration 30: Global best score = -78.33072522092678
# Iteration 40: Global best score = -78.33072522092678
# Iteration 50: Global best score = -78.33117870911289
# Iteration 60: Global best score = -78.33117870911289
# Target global minimum -78.33198 reached at iteration 69. Stopping.
# Iteration 0: Global best score = -63.79456195363869
# Iteration 10: Global best score = -78.23023697071875
# Iteration 20: Global best score = -78.29259007323415
# Iteration 30: Global best score = -78.32251390641241
# Iteration 40: Global best score = -78.33006200736304
# Iteration 50: Global best score = -78.33064377102654
# Iteration 60: Global best score = -78.33109185941436
# Iteration 70: Global best score = -78.33181455084802
# Target global minimum -78.33198 reached at iteration 75. Stopping.
# Iteration 0: Global best score = -63.961255171549254
# Iteration 10: Global best score = -78.11073519141391
# Iteration 20: Global best score = -78.18316571571361
# Iteration 30: Global best score = -78.32709381756624
# Iteration 40: Global best score = -78.32709381756624
# Target global minimum -78.33198 reached at iteration 41. Stopping.
# Iteration 0: Global best score = -77.74947576247176
# Iteration 10: Global best score = -78.12911048414162
# Iteration 20: Global best score = -78.21349301245253
# Iteration 30: Global best score = -78.32755250799211
# Iteration 40: Global best score = -78.32899304776356
# Target global minimum -78.33198 reached at iteration 50. Stopping.
# Iteration 0: Global best score = -78.16057717887628
# Iteration 10: Global best score = -78.31642138772558
# Iteration 20: Global best score = -78.31642138772558
# Iteration 30: Global best score = -78.32569687923066
# Target global minimum -78.33198 reached at iteration 35. Stopping.
# Function: styblinski_tang
# Best parameters: num_particles = 20, alpha1 = 1.5, alpha2 = 1
# Average cost (num_particles * iterations): 1296.00
# --------------------------------------------------

# %%
for func_name, (best_params, best_avg_cost, param_results) in results.items():
    print(f"Function: {func_name}")
    print(f"Best parameters: num_particles = {best_params[0]}, alpha1 = {best_params[1]}, alpha2 = {best_params[2]}")
    print(f"Average cost (num_particles * iterations): {best_avg_cost:.2f}")
    print("-" * 50)
# Out:
# Function: ackley
# Best parameters: num_particles = 20, alpha1 = 1, alpha2 = 0.5
# Average cost (num_particles * iterations): 2566.00
# --------------------------------------------------
# Function: rosenbrock
# Best parameters: num_particles = 20, alpha1 = 1, alpha2 = 0.5
# Average cost (num_particles * iterations): 2062.00
# --------------------------------------------------
# Function: cross_in_tray
# Best parameters: num_particles = 20, alpha1 = 1.5, alpha2 = 0.5
# Average cost (num_particles * iterations): 1142.00
# --------------------------------------------------
# Function: holder_table
# Best parameters: num_particles = 20, alpha1 = 2, alpha2 = 2
# Average cost (num_particles * iterations): 310.00
# --------------------------------------------------
# Function: mccormick
# Best parameters: num_particles = 250, alpha1 = 2, alpha2 = 2
# Average cost (num_particles * iterations): 3075.00
# --------------------------------------------------
# Function: styblinski_tang
# Best parameters: num_particles = 20, alpha1 = 1.5, alpha2 = 1
# Average cost (num_particles * iterations): 1296.00
# --------------------------------------------------

# %% [markdown]
# ## Visualise process of finding global minimum

# %%
best_params = {
    "styblinski_tang": (20, 1, 0.5),
    "mccormick": (20, 1, 0.5),
    "holder_table": (20, 1.5, 0.5),
    "ackley": (20, 2, 2),
    "cross_in_tray": (250, 2, 2),
    "rosenbrock": (500, 2, 2)
}

# %%
w_max = 0.9
w_min = 0.2
max_iter = 500
enable_shaking = False
stagnation_iter = 50
shake_probability = 0.5
shake_amplitude = 0.1
epsilon_target = 1e-6
epsilon_stagnation = 1e-6

for func_name, (func, x_bound, y_bound, best_point, theoretical_min) in func_info.items():
    n, a1, a2 = best_params[func_name]
    bounds = np.array([x_bound, y_bound])
    
    print(f"Running PSO for {func_name} with parameters: num_particles={n}, alpha1={a1}, alpha2={a2}")
    
    pso_solver = PSO(func, n, 2, bounds, (-2, 2), max_iter,
                     a1, a2, w_max, w_min,
                     enable_shaking, stagnation_iter, shake_probability, shake_amplitude,
                     target_global_min=theoretical_min, epsilon_target=epsilon_target, epsilon_stagnation=epsilon_stagnation)
    global_best_position, best_score, history_best_positions, _ = pso_solver.run()

    history_best_values = [func(np.array(pos)) for pos in history_best_positions]
    iterations = np.arange(len(history_best_values))

    plt.figure(figsize=(8,6))
    plt.plot(iterations, history_best_values, marker='o', markersize=3, linewidth=1)
    plt.xlabel("Iteration")
    plt.ylabel("Best Function Value")
    plt.title(f"{func_name.capitalize()} Function (Theoretical Global Min: {theoretical_min})\n"
              f"Optimal Parameters: num_particles={n}, alpha1={a1}, alpha2={a2}\n"
              f"Convergence achieved at iteration {len(history_best_values)-1}")
    plt.grid(True)
    plt.show()
# Out:
# Running PSO for ackley with parameters: num_particles=20, alpha1=2, alpha2=2
# Iteration 0: Global best score = 4.181280608407096
# Iteration 10: Global best score = 0.7973439995016354
# Iteration 20: Global best score = 0.25783657384810654
# Iteration 30: Global best score = 0.25783657384810654
# Iteration 40: Global best score = 0.25783657384810654
# Iteration 50: Global best score = 0.25783657384810654
# Iteration 60: Global best score = 0.15772253625798927
# Iteration 70: Global best score = 0.15569106013254386
# Iteration 80: Global best score = 0.14751752415568165
# Iteration 90: Global best score = 0.03225365222546417
# Iteration 100: Global best score = 0.0215685694450376
# Iteration 110: Global best score = 0.0215685694450376
# Iteration 120: Global best score = 0.013611764126022496
# Iteration 130: Global best score = 0.0035637935555716815
# Iteration 140: Global best score = 0.002311756835684964
# Iteration 150: Global best score = 0.0008512134160452156
# Iteration 160: Global best score = 0.0008512134160452156
# Iteration 170: Global best score = 0.0002178457208903417
# Iteration 180: Global best score = 0.00014437103887177116
# Iteration 190: Global best score = 0.00010570563656076004
# Iteration 200: Global best score = 5.022212019145655e-06
# Iteration 210: Global best score = 5.022212019145655e-06
# Iteration 220: Global best score = 2.3555688781762285e-06
# Iteration 230: Global best score = 1.7987248885908969e-06
# Global minimum is within epsilon 1e-06 of target at iteration 237. Stopping.
# Running PSO for rosenbrock with parameters: num_particles=500, alpha1=2, alpha2=2
# Iteration 0: Global best score = 0.11263517083502932
# Iteration 10: Global best score = 0.018919100168084707
# Iteration 20: Global best score = 0.013670723100766115
# Iteration 30: Global best score = 0.013670723100766115
# Iteration 40: Global best score = 0.008071085804939645
# Iteration 50: Global best score = 0.0034458024429656437
# Iteration 60: Global best score = 0.0005228758784877154
# Iteration 70: Global best score = 3.941188461558805e-05
# Iteration 80: Global best score = 3.941188461558805e-05
# Iteration 90: Global best score = 3.941188461558805e-05
# Iteration 100: Global best score = 3.941188461558805e-05
# Iteration 110: Global best score = 2.9886296003460395e-06
# Iteration 120: Global best score = 2.701819422963702e-06
# Global minimum is within epsilon 1e-06 of target at iteration 123. Stopping.
# Running PSO for cross_in_tray with parameters: num_particles=250, alpha1=2, alpha2=2
# Iteration 0: Global best score = -2.0469008831261197
# Iteration 10: Global best score = -2.0621134897847213
# Iteration 20: Global best score = -2.0624458373211385
# Iteration 30: Global best score = -2.0624458373211385
# Iteration 40: Global best score = -2.0624458373211385
# Iteration 50: Global best score = -2.0625059387152023
# Iteration 60: Global best score = -2.0625610843505644
# Iteration 70: Global best score = -2.0625955898635233
# Iteration 80: Global best score = -2.0625955898635233
# Iteration 90: Global best score = -2.0625955898635233
# Iteration 100: Global best score = -2.0625955898635233
# Iteration 110: Global best score = -2.0625955898635233
# Global minimum is within epsilon 1e-06 of target at iteration 113. Stopping.
# Running PSO for holder_table with parameters: num_particles=20, alpha1=1.5, alpha2=0.5
# Iteration 0: Global best score = -17.76557816745969
# Iteration 10: Global best score = -19.12556957769272
# Iteration 20: Global best score = -19.208116939197126
# Iteration 30: Global best score = -19.208116939197126
# Iteration 40: Global best score = -19.20820085190269
# Iteration 50: Global best score = -19.20825046112179
# Iteration 60: Global best score = -19.208489176243802
# Target global minimum -19.2085 reached at iteration 62. Stopping.
# Running PSO for mccormick with parameters: num_particles=20, alpha1=1, alpha2=0.5
# Iteration 0: Global best score = 9.298982627198804
# Iteration 10: Global best score = -1.8762538360514371
# Iteration 20: Global best score = -1.906880499970339
# Iteration 30: Global best score = -1.9130269993514109
# Iteration 40: Global best score = -1.9131504675060214
# Iteration 50: Global best score = -1.9132094515778233
# Iteration 60: Global best score = -1.9132203268754475
# Iteration 70: Global best score = -1.9132203268754475
# Iteration 80: Global best score = -1.9132227766789427
# Iteration 90: Global best score = -1.9132229468670197
# Iteration 100: Global best score = -1.9132229544069608
# Iteration 110: Global best score = -1.913222954533257
# Iteration 120: Global best score = -1.9132229549709616
# Iteration 130: Global best score = -1.9132229549804878
# Iteration 140: Global best score = -1.9132229549810327
# Iteration 150: Global best score = -1.9132229549810362
# Iteration 160: Global best score = -1.9132229549810367
# Iteration 170: Global best score = -1.9132229549810367
# Iteration 180: Global best score = -1.9132229549810367
# Iteration 190: Global best score = -1.9132229549810367
# Iteration 200: Global best score = -1.9132229549810367
# Iteration 210: Global best score = -1.9132229549810367
# Iteration 220: Global best score = -1.9132229549810367
# Iteration 230: Global best score = -1.9132229549810367
# Iteration 240: Global best score = -1.9132229549810367
# Iteration 250: Global best score = -1.9132229549810367
# Iteration 260: Global best score = -1.9132229549810367
# Iteration 270: Global best score = -1.9132229549810367
# Iteration 280: Global best score = -1.9132229549810367
# Iteration 290: Global best score = -1.9132229549810367
# Iteration 300: Global best score = -1.9132229549810367
# Iteration 310: Global best score = -1.9132229549810367
# Iteration 320: Global best score = -1.9132229549810367
# Iteration 330: Global best score = -1.9132229549810367
# Iteration 340: Global best score = -1.9132229549810367
# Iteration 350: Global best score = -1.9132229549810367
# Iteration 360: Global best score = -1.9132229549810367
# Iteration 370: Global best score = -1.9132229549810367
# Iteration 380: Global best score = -1.9132229549810367
# Iteration 390: Global best score = -1.9132229549810367
# Iteration 400: Global best score = -1.9132229549810367
# Iteration 410: Global best score = -1.9132229549810367
# Iteration 420: Global best score = -1.9132229549810367
# Iteration 430: Global best score = -1.9132229549810367
# Iteration 440: Global best score = -1.9132229549810367
# Iteration 450: Global best score = -1.9132229549810367
# Iteration 460: Global best score = -1.9132229549810367
# Iteration 470: Global best score = -1.9132229549810367
# Iteration 480: Global best score = -1.9132229549810367
# Iteration 490: Global best score = -1.9132229549810367
# Running PSO for styblinski_tang with parameters: num_particles=20, alpha1=1, alpha2=0.5
# Iteration 0: Global best score = -62.64936354266137
# Iteration 10: Global best score = -64.12289735135114
# Iteration 20: Global best score = -64.19228435605811
# Iteration 30: Global best score = -76.42838029262758
# Iteration 40: Global best score = -78.2847110569906
# Iteration 50: Global best score = -78.31278897765893
# Iteration 60: Global best score = -78.33112884420379
# Iteration 70: Global best score = -78.33117845655812
# Target global minimum -78.33198 reached at iteration 77. Stopping.

# %% [markdown]
# # GIFs

# %%
def create_surface_gif(func, bounds, best_points, all_populations, filename="optimization_surface", save_gif=False, show=False):
    """
    Creates an animated GIF using a 3D surface plot of the objective function.

    Parameters:
        func (callable): The objective function.
        bounds (ndarray): 2x2 array with bounds [[x_min, x_max], [y_min, y_max]].
        best_points (list): List of best point coordinates per iteration.
        all_populations (list): List of arrays containing all particle positions per iteration.
        filename (str): Base filename for the output GIF.
        save_gif (bool): If True, saves the animation as a GIF.
        show (bool): If True, displays the animation.

    Returns:
        ani (FuncAnimation): The animation object.
    """
    # Создание сетки для построения поверхности
    x = np.linspace(bounds[0, 0], bounds[0, 1], 100)
    y = np.linspace(bounds[1, 0], bounds[1, 1], 100)
    X, Y = np.meshgrid(x, y)

    # Функция должна получать входные значения в виде массива shape (2,) и возвращать одно число
    def eval_func(X, Y):
        XY_pairs = np.column_stack((X.ravel(), Y.ravel()))  # Преобразуем в (N, 2)
        Z = np.array([func(point) for point in XY_pairs])  # Применяем func() ко всем точкам
        return Z.reshape(X.shape)  # Преобразуем обратно в 2D

    Z = eval_func(X, Y)  # Теперь Z имеет правильный размер (100, 100)

    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, Z, cmap='viridis', alpha=0.7)
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_zlabel("Z")
    ax.set_title("Optimization Progress (Surface)")

    pop_scatter = ax.scatter([], [], [], color='red', s=20, label='Population')
    best_scatter = ax.scatter([], [], [], color='yellow', s=50, label='Best')

    def init():
        pop_scatter._offsets3d = ([], [], [])
        best_scatter._offsets3d = ([], [], [])
        return pop_scatter, best_scatter

    def update(frame):
        # Обновляем позиции частиц
        population = np.array(all_populations[frame])
        pop_z = np.array([func(ind) for ind in population])  # Оставляем input как (2,)
        pop_scatter._offsets3d = (population[:, 0], population[:, 1], pop_z)

        # Обновляем лучшую точку
        best_x, best_y = best_points[frame]
        best_z = func(np.array([best_x, best_y]))  # Вызываем напрямую
        best_scatter._offsets3d = ([best_x], [best_y], [best_z])

        ax.set_title(f"Surface Plot (Iteration {frame+1})")
        return pop_scatter, best_scatter

    ani = animation.FuncAnimation(fig, update, frames=len(best_points), init_func=init, blit=True, repeat=False)
    
    if save_gif:
        ani.save(filename + '.gif', writer="pillow", fps=5)
    if show:
        plt.show()
    else:
        plt.close()

    return ani

# %%
best_params = {
    "ackley": (20, 2, 2),
    "rosenbrock": (500, 2, 2),
    "cross_in_tray": (250, 2, 2),
    "holder_table": (20, 1.5, 0.5),
    "mccormick": (20, 1, 0.5),
    "styblinski_tang": (20, 1, 0.5)
}
func_info = {
    "ackley": (ackley, (-5, 5), (-5, 5), (0, 0), 0),
    "rosenbrock": (rosenbrock, (-5, 5), (-5, 5), (1, 1), 0),
    "cross_in_tray": (cross_in_tray, (-10, 10), (-10, 10), (1.34941, 1.34941), -2.06261),
    "holder_table": (holder_table, (-10, 10), (-10, 10), (8.05502, 9.66459), -19.2085),
    "mccormick": (mccormick, (-1.5, 4), (-3, 4), (-0.54719, -1.54719), -1.9133),
    "styblinski_tang": (styblinski_tang, (-5, 5), (-5, 5), (-2.903534, -2.903534), -78.33198)
}

# %%
# Fixed PSO parameters
w_max = 0.9
w_min = 0.2
max_iter = 500
enable_shaking = True
stagnation_iter = 50
shake_probability = 0.5
shake_amplitude = 0.3
epsilon_target = 1e-6
epsilon_stagnation = 1e-6

for func_name, (n, a1, a2) in best_params.items():
    func, x_bound, y_bound, best_point, theoretical_min = func_info[func_name]

    bounds = np.array([x_bound, y_bound])
    
    print(f"Running PSO for {func_name} with parameters: num_particles={n}, alpha1={a1}, alpha2={a2}")

    pso_solver = PSO(func, n, 2, bounds, (-2, 2), max_iter,
                     a1, a2, w_max, w_min,
                     enable_shaking, stagnation_iter, shake_probability, shake_amplitude,
                     target_global_min=theoretical_min, epsilon_target=epsilon_target, epsilon_stagnation=epsilon_stagnation)
    global_best_position, best_score, history_best_positions, history_all_positions = pso_solver.run()
    
    # Create and save the surface GIF
    surface_filename = f"{func_name}_surface"
    ani_surface = create_surface_gif(func, bounds, history_best_positions, history_all_positions,
                                     filename=surface_filename, save_gif=True, show=False)

    
    print(f"GIFs for {func_name} saved as '{surface_filename}.gif'")
# Out:
# Running PSO for ackley with parameters: num_particles=20, alpha1=2, alpha2=2
# Iteration 0: Global best score = 0.6033018595704829
# Iteration 10: Global best score = 0.18421093297713798
# Iteration 20: Global best score = 0.18421093297713798
# Iteration 30: Global best score = 0.18421093297713798
# Iteration 40: Global best score = 0.18421093297713798
# Iteration 50: Global best score = 0.1154513102510113
# Iteration 60: Global best score = 0.1154513102510113
# Iteration 70: Global best score = 0.1154513102510113
# Iteration 80: Global best score = 0.10770417842596958
# Iteration 90: Global best score = 0.04753115862217472
# Iteration 100: Global best score = 0.04512458686509335
# Iteration 110: Global best score = 0.01972773589190213
# Iteration 120: Global best score = 0.00940598498159817
# Iteration 130: Global best score = 0.0007099295939210215
# Iteration 140: Global best score = 0.0006242547038621815
# Iteration 150: Global best score = 0.0003337849382671898
# Iteration 160: Global best score = 0.0003298887249703064
# Iteration 170: Global best score = 4.492941252154381e-05
# Iteration 180: Global best score = 1.7607881208636655e-05
# Iteration 190: Global best score = 1.536230098553304e-05
# Iteration 200: Global best score = 4.558631691242709e-06
# Iteration 210: Global best score = 1.1945278726166464e-06
# Global minimum is within epsilon 1e-06 of target at iteration 212. Stopping.
# GIFs for ackley saved as 'ackley_surface.gif'
# Running PSO for rosenbrock with parameters: num_particles=500, alpha1=2, alpha2=2
# Iteration 0: Global best score = 0.3281218212087742
# Iteration 10: Global best score = 0.07495498042216842
# Iteration 20: Global best score = 0.02210953374428484
# Iteration 30: Global best score = 0.02210953374428484
# Iteration 40: Global best score = 0.010540539222380185
# Iteration 50: Global best score = 0.004154396075859528
# Iteration 60: Global best score = 0.0016462075443828142
# Iteration 70: Global best score = 0.0002616084907531458
# Iteration 80: Global best score = 0.0002616084907531458
# Iteration 90: Global best score = 6.96001638426759e-05
# Iteration 100: Global best score = 2.4783065905696946e-05
# Iteration 110: Global best score = 6.541840761373017e-06
# Global minimum is within epsilon 1e-06 of target at iteration 116. Stopping.
# GIFs for rosenbrock saved as 'rosenbrock_surface.gif'
# Running PSO for cross_in_tray with parameters: num_particles=250, alpha1=2, alpha2=2
# Iteration 0: Global best score = -2.061488048092292
# Iteration 10: Global best score = -2.062376922149816
# Iteration 20: Global best score = -2.062376922149816
# Iteration 30: Global best score = -2.0624957110068736
# Iteration 40: Global best score = -2.0625348613697674
# Iteration 50: Global best score = -2.0625907308428575
# Iteration 60: Global best score = -2.062602491628181
# Iteration 70: Global best score = -2.0626062818982143
# Iteration 80: Global best score = -2.0626076690928805
# Global minimum is within epsilon 1e-06 of target at iteration 86. Stopping.
# GIFs for cross_in_tray saved as 'cross_in_tray_surface.gif'
# Running PSO for holder_table with parameters: num_particles=20, alpha1=1.5, alpha2=0.5
# Iteration 0: Global best score = -15.140223856952055
# Iteration 10: Global best score = -16.037526767660985
# Iteration 20: Global best score = -16.160243037576233
# Iteration 30: Global best score = -19.16036713721509
# Iteration 40: Global best score = -19.183701156158257
# Iteration 50: Global best score = -19.20478110230161
# Iteration 60: Global best score = -19.208417758590382
# Iteration 70: Global best score = -19.208457771703944
# Target global minimum -19.2085 reached at iteration 79. Stopping.
# GIFs for holder_table saved as 'holder_table_surface.gif'
# Running PSO for mccormick with parameters: num_particles=20, alpha1=1, alpha2=0.5
# Iteration 0: Global best score = 9.749953838218913
# Iteration 10: Global best score = -1.908870784004289
# Iteration 20: Global best score = -1.9127776712412001
# Iteration 30: Global best score = -1.9130784961228242
# Iteration 40: Global best score = -1.9131276291986747
# Iteration 50: Global best score = -1.913144037636993
# Iteration 60: Global best score = -1.9132179148433854
# Iteration 70: Global best score = -1.9132217967840548
# Iteration 80: Global best score = -1.9132229442464639
# Iteration 90: Global best score = -1.9132229471152167
# Iteration 100: Global best score = -1.9132229543048052
# Iteration 110: Global best score = -1.913222954953869
# Iteration 120: Global best score = -1.9132229549788446
# Stagnation reached at iteration 124. Shaking particles...
# Shaken 9 particles.
# Iteration 130: Global best score = -1.9132229549809905
# Iteration 140: Global best score = -1.9132229549810242
# Iteration 150: Global best score = -1.9132229549810358
# Iteration 160: Global best score = -1.9132229549810367
# Iteration 170: Global best score = -1.9132229549810367
# Stagnation reached at iteration 174. Shaking particles...
# Shaken 6 particles.
# Iteration 180: Global best score = -1.9132229549810367
# Iteration 190: Global best score = -1.9132229549810367
# Iteration 200: Global best score = -1.9132229549810367
# Iteration 210: Global best score = -1.9132229549810367
# Iteration 220: Global best score = -1.9132229549810367
# Stagnation reached at iteration 224. Shaking particles...
# Shaken 9 particles.
# Iteration 230: Global best score = -1.9132229549810367
# Iteration 240: Global best score = -1.9132229549810367
# Iteration 250: Global best score = -1.9132229549810367
# Iteration 260: Global best score = -1.9132229549810367
# Iteration 270: Global best score = -1.9132229549810367
# Stagnation reached at iteration 274. Shaking particles...
# Shaken 11 particles.
# Iteration 280: Global best score = -1.9132229549810367
# Iteration 290: Global best score = -1.9132229549810367
# Iteration 300: Global best score = -1.9132229549810367
# Iteration 310: Global best score = -1.9132229549810367
# Iteration 320: Global best score = -1.9132229549810367
# Stagnation reached at iteration 324. Shaking particles...
# Shaken 10 particles.
# Iteration 330: Global best score = -1.9132229549810367
# Iteration 340: Global best score = -1.9132229549810367
# Iteration 350: Global best score = -1.9132229549810367
# Iteration 360: Global best score = -1.9132229549810367
# Iteration 370: Global best score = -1.9132229549810367
# Stagnation reached at iteration 374. Shaking particles...
# Shaken 9 particles.
# Iteration 380: Global best score = -1.9132229549810367
# Iteration 390: Global best score = -1.9132229549810367
# Iteration 400: Global best score = -1.9132229549810367
# Iteration 410: Global best score = -1.9132229549810367
# Iteration 420: Global best score = -1.9132229549810367
# Stagnation reached at iteration 424. Shaking particles...
# Shaken 9 particles.
# Iteration 430: Global best score = -1.9132229549810367
# Iteration 440: Global best score = -1.9132229549810367
# Iteration 450: Global best score = -1.9132229549810367
# Iteration 460: Global best score = -1.9132229549810367
# Iteration 470: Global best score = -1.9132229549810367
# Stagnation reached at iteration 474. Shaking particles...
# Shaken 11 particles.
# Iteration 480: Global best score = -1.9132229549810367
# Iteration 490: Global best score = -1.9132229549810367
# GIFs for mccormick saved as 'mccormick_surface.gif'
# Running PSO for styblinski_tang with parameters: num_particles=20, alpha1=1, alpha2=0.5
# Iteration 0: Global best score = -56.44109621501434
# Iteration 10: Global best score = -64.06246075053787
# Iteration 20: Global best score = -64.18949954916738
# Iteration 30: Global best score = -64.1948694477523
# Iteration 40: Global best score = -64.19531012553232
# Iteration 50: Global best score = -64.19548115108731
# Iteration 60: Global best score = -64.19560191666666
# Iteration 70: Global best score = -64.1956123251845
# Iteration 80: Global best score = -64.1956123251845
# Iteration 90: Global best score = -64.19561234238891
# Iteration 100: Global best score = -64.19561235656329
# Iteration 110: Global best score = -64.19561235870064
# Stagnation reached at iteration 117. Shaking particles...
# Shaken 9 particles.
# Iteration 120: Global best score = -64.19561235904509
# Iteration 130: Global best score = -64.19561235905482
# Iteration 140: Global best score = -64.19561235905489
# Iteration 150: Global best score = -64.19561235905535
# Iteration 160: Global best score = -64.19561235905536
# Stagnation reached at iteration 167. Shaking particles...
# Shaken 10 particles.
# Iteration 170: Global best score = -64.19561235905536
# Iteration 180: Global best score = -64.19561235905536
# Iteration 190: Global best score = -64.19561235905536
# Iteration 200: Global best score = -64.19561235905536
# Iteration 210: Global best score = -64.19561235905537
# Stagnation reached at iteration 217. Shaking particles...
# Shaken 10 particles.
# Iteration 220: Global best score = -64.19561235905537
# Iteration 230: Global best score = -64.19561235905537
# Iteration 240: Global best score = -64.19561235905537
# Iteration 250: Global best score = -64.19561235905537
# Iteration 260: Global best score = -64.19561235905537
# Stagnation reached at iteration 267. Shaking particles...
# Shaken 11 particles.
# Iteration 270: Global best score = -64.19561235905537
# Iteration 280: Global best score = -64.19561235905537
# Iteration 290: Global best score = -64.19561235905537
# Iteration 300: Global best score = -64.19561235905537
# Iteration 310: Global best score = -64.19561235905537
# Stagnation reached at iteration 317. Shaking particles...
# Shaken 11 particles.
# Iteration 320: Global best score = -64.19561235905537
# Iteration 330: Global best score = -64.19561235905537
# Iteration 340: Global best score = -64.19561235905537
# Iteration 350: Global best score = -64.19561235905537
# Iteration 360: Global best score = -64.19561235905537
# Stagnation reached at iteration 367. Shaking particles...
# Shaken 7 particles.
# Iteration 370: Global best score = -64.19561235905537
# Iteration 380: Global best score = -64.19561235905537
# Iteration 390: Global best score = -64.19561235905537
# Iteration 400: Global best score = -64.19561235905537
# Iteration 410: Global best score = -64.19561235905537
# Stagnation reached at iteration 417. Shaking particles...
# Shaken 8 particles.
# Iteration 420: Global best score = -64.19561235905537
# Iteration 430: Global best score = -64.19561235905537
# Iteration 440: Global best score = -64.19561235905537
# Iteration 450: Global best score = -64.19561235905537
# Iteration 460: Global best score = -64.19561235905537
# Stagnation reached at iteration 467. Shaking particles...
# Shaken 12 particles.
# Iteration 470: Global best score = -64.19561235905537
# Iteration 480: Global best score = -64.19561235905537
# Iteration 490: Global best score = -64.19561235905537
# GIFs for styblinski_tang saved as 'styblinski_tang_surface.gif'
